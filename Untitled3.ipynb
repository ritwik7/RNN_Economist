# %%
import tensorflow as tf
import keras
import numpy as np
import os
# to make this notebook's output stable across runs
def reset_graph(seed=42):
    tf.reset_default_graph()
    tf.set_random_seed(seed)
    np.random.seed(seed)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

import pandas as pd
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, LabelEncoder
import seaborn as sns

import scipy.stats as sc_stats

import random

from sklearn.model_selection import train_test_split
onehot_encoder=OneHotEncoder(sparse=False)

from tensorflow.contrib import rnn

os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# Using TensorFlow backend.

# %%
# Data Dimension
inputs = 3          # MNIST data input (image shape: 28x28)
timesteps = 29         # Timesteps
outputs= 1         # Number of classes, one class per digit

# %%
def add_releveant_features(task_df):


    task_df['PrevOutcome']=task_df['Outcome'].shift(1)
    task_df.loc[1,'PrevOutcome']= 0

    task_df['PrevChoice']=task_df['Choice'].shift(1)
    task_df.loc[1,'PrevChoice']= 0

    task_df['PrevSafe']=task_df['Safe'].shift(1)
    task_df.loc[1,'PrevSafe']= 0

    task_df['PrevBigRisky']=task_df['BigRisky'].shift(1)
    task_df.loc[1,'PrevBigRisky']= 0

    task_df['PrevSmallRisky']=task_df['SmallRisky'].shift(1)
    task_df.loc[1,'PrevSmallRisky']= 0
    
#     task_df['PrevRT']=task_df['RT'].shift(1)
#     task_df.loc[1,'PrevRT']= 0
    
    
    
    return task_df

# %%
def randomize(x, y):
    """ Randomizes the order of data samples and their corresponding labels"""
    permutation = np.random.permutation(y.shape[0])
    shuffled_x = x[permutation, :]
    shuffled_y = y[permutation]
    return shuffled_x, shuffled_y

def get_next_batch(x, y, start, end):
    x_batch = x[start:end]
    y_batch = y[start:end]
    return x_batch, y_batch

# %%
def train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y): 
    reset_graph()

    learning_rate = 0.001
    epochs = 10000
    batch_size = int(train_X.shape[0]/2)
    # batch_size = 100
    length = train_X.shape[0]
    display = 100
    neurons = neurons

    num_batches = 100
    seq_len = 10


    train_threshold = 1.5#PT_R2 + percent_above_PT


    save_step = 100


    best_loss_val = np.infty
    checks_since_last_progress = 0
    max_checks_without_progress = 1000

    
    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, num_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, num_input)
    X = tf.unstack(train_X, timesteps,1)

    
    

    # clear graph (if any) before running
    tf.reset_default_graph()

    X = tf.placeholder(tf.float32, shape=[None, timesteps, inputs], name='X')
    y = tf.placeholder(tf.float32, shape=[None, timesteps outputs], name='Y')


    # LSTM Cell
    cell = tf.contrib.rnn.BasicLSTMCell(num_units=neurons, activation=tf.nn.relu)
    cell_outputs, states = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)

    # pass into Dense layer
#     stacked_outputs = tf.reshape(cell_outputs, [-1, neurons])
#     out = tf.layers.dense(inputs=stacked_outputs, units=outputs)

    out = tf.layers.dense(inputs=cell_outputs, units=outputs)

    probability = tf.nn.softmax(out)

    # squared error loss or cost function for linear regression
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(
            labels=y, logits=out))

    # optimizer to minimize cost
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
    training_op = optimizer.minimize(loss)
    saver = tf.train.Saver()
    
    
    correct_prediction = tf.equal(tf.argmax(out, 1), tf.argmax(y, 1), name='correct_pred')
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')

    
#     accuracy = tf.metrics.accuracy(labels =  tf.argmax(y, 1),
#                           predictions = tf.argmax(out, 1),
#                           name = "accuracy")
#     precision = tf.metrics.precision(labels=tf.argmax(y, 1),
#                                  predictions=tf.argmax(out, 1),
#                                  name="precision")
#     recall = tf.metrics.recall(labels=tf.argmax(y, 1),
#                            predictions=tf.argmax(out, 1),
#                            name="recall")
#     f1 = 2 * accuracy[1] * recall[1] / ( precision[1] + recall[1] )

#     acc_up,acc_val = accuracy
#     auc = tf.metrics.auc(labels=tf.argmax(y, 1),
#                            predictions=tf.argmax(out, 1),
#                            name="auc")
    
    
    valid_store = []
    
    init = tf.global_variables_initializer()

    sess = tf.InteractiveSession()
    sess.run(init)
    global_step = 0
# Number of training iterations in each epoch
    num_tr_iter = int(len(train_y) / batch_size)
    for epoch in range(epochs):
        print('Training epoch: {}'.format(epoch + 1))
        train_X, train_y = randomize(train_X, train_y)
        for iteration in range(num_tr_iter):
            global_step += 1
            start = iteration * batch_size
            end = (iteration + 1) * batch_size
            x_batch, y_batch = get_next_batch(train_X, train_y, start, end)
            x_batch = x_batch.reshape((batch_size, timesteps, inputs))
            
            print(x_batch)
            # Run optimization op (backprop)
            feed_dict_batch = {X: x_batch, y: y_batch}
            sess.run(optimizer, feed_dict=feed_dict_batch)

            if iteration % display_freq == 0:
                # Calculate and display the batch loss and accuracy
                loss_batch, acc_batch = sess.run([loss, accuracy],
                                                 feed_dict=feed_dict_batch)

                print("iter {0:3d}:\t Loss={1:.2f},\tTraining Accuracy={2:.01%}".
                      format(iteration, loss_batch, acc_batch))

    # Run validation after every epoch

        feed_dict_valid = {X: x_valid[:1000].reshape((-1, timesteps, num_input)), y: y_valid[:1000]}
        loss_valid, acc_valid = sess.run([loss, accuracy], feed_dict=feed_dict_valid)
        print('---------------------------------------------------------')
        print("Epoch: {0}, validation loss: {1:.2f}, validation accuracy: {2:.01%}".
              format(epoch + 1, loss_valid, acc_valid))
        print('---------------------------------------------------------')
# Out:
#   File "<ipython-input-5-23df213a9dbb>", line 41
#     y = tf.placeholder(tf.float32, shape=[None, timesteps outputs], name='Y')
#                                                                 ^
# SyntaxError: invalid syntax

# %%
dir_list = os.listdir("/Users/ritwik7/Dropbox (Personal)/Postdoc_UCL/DATA/rlab_incomplete_rewardSWB_code/by_RN/appdata/")
dir_path ="/Users/ritwik7/Dropbox (Personal)/Postdoc_UCL/DATA/rlab_incomplete_rewardSWB_code/by_RN/appdata/"

subj_files_list =[]; ## list of subject_files fullfilling a criteria

dir_files = [i for i in os.listdir(dir_path) if i.startswith('sub')]

for subj_file_path in dir_files:

    file_path  ="/Users/ritwik7/Dropbox (Personal)/Postdoc_UCL/DATA/rlab_incomplete_rewardSWB_code/by_RN/appdata/"+ subj_file_path
    mypath =file_path
    
    play_names = [i for i in os.listdir(mypath) if os.path.isfile(os.path.join(mypath,i)) and i.startswith('app')]   
    
    if len(play_names) >= 50: ## criteria
        subj_files_list.append(subj_file_path)

# %%
neurons=8
pretraining=False

for num, subj_file_path in enumerate([subj_files_list[0]]):

    file_path  ="/Users/ritwik7/Dropbox (Personal)/Postdoc_UCL/DATA/rlab_incomplete_rewardSWB_code/by_RN/appdata/"+ subj_file_path
                
#     file_path = file_path + "/OddEvenPlays"
    file_path = file_path + "/OddEvenPlays/RandomizedPlays1"

    train_data_df= pd.read_csv(file_path+"/train_data.csv")
    test_data_df = pd.read_csv(file_path+"/test_data.csv")
    val_data_df = pd.read_csv(file_path+"/val_data.csv")
    
    
    
    train_X = train_data_df[['Safe','BigRisky','SmallRisky']].values.reshape(-1,timesteps,inputs)
    train_y = train_data_df[['Choice']].values.astype(np.int32).reshape(-1,timesteps,outputs)

    test_X = test_data_df[['Safe','BigRisky','SmallRisky']].values.reshape(-1,13,inputs)
    test_y = test_data_df[['Choice']].values.astype(np.int32).reshape(-1,13,outputs)

    val_X = val_data_df[['Safe','BigRisky','SmallRisky']].values.reshape(-1,16,inputs)
    val_y = val_data_df[['Choice']].values.astype(np.int32).reshape(-1,16,outputs)
        
    scaler = MinMaxScaler(feature_range=(0, 1))    
#     train_X = scaler.fit_transform(train_X[:,])
#     test_X = scaler.fit_transform(test_X)
#     val_X = scaler.fit_transform(val_X)


#     train_X = train_X[:,None,:]
#     val_X = val_X[:,None,:]
#     test_X = test_X[:,None,:]


    # # one-hot encode the outputs

#     onehot_encoder = OneHotEncoder()
#     encode_categorical = train_y.reshape(len(train_y), 1)
#     encode_categorical_test = test_y.reshape(len(test_y), 1)
#     encode_categorical_val = val_y.reshape(len(val_y),1)


#     train_y = onehot_encoder.fit_transform(encode_categorical).toarray()
#     test_y = onehot_encoder.fit_transform(encode_categorical_test).toarray()
#     val_y = onehot_encoder.fit_transform(encode_categorical_val).toarray()


    
    
#     metric_out_df, prob_train, prob_test, prob_val = train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)
    train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-7-169372b9181a> in <module>
#      51
#      52 #     metric_out_df, prob_train, prob_test, prob_val = train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)
# ---> 53     train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)
#
# NameError: name 'train_RNN' is not defined

# %%
train_y.shape

# %%
train_X.shape
# Out:
# (41, 29, 3)

# %%
train_X.shape
# Out:
# (41, 29, 3)

# %%
x_batch
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-39-e64391fe376a> in <module>
# ----> 1 x_batch
#
# NameError: name 'x_batch' is not defined

# %%
y_batch.shape
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-22-6134c0f4a38d> in <module>
# ----> 1 y_batch.shape
#
# NameError: name 'y_batch' is not defined

# %%
tf.unstack(train_X, timesteps,1)
# Out:
# [<tf.Tensor 'unstack_6:0' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:1' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:2' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:3' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:4' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:5' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:6' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:7' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:8' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:9' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:10' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:11' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:12' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:13' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:14' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:15' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:16' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:17' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:18' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:19' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:20' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:21' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:22' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:23' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:24' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:25' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:26' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:27' shape=(41, 3) dtype=float64>,
#  <tf.Tensor 'unstack_6:28' shape=(41, 3) dtype=float64>]

# %%
num_input = 28          # MNIST data input (image shape: 28x28)
timesteps = 28          # Timesteps
n_classes = 10          # Number of classes, one class per digit

# %%
def load_data(mode='train'):
    """
    Function to (download and) load the MNIST data
    :param mode: train or test
    :return: images and the corresponding labels
    """
    from tensorflow.examples.tutorials.mnist import input_data
    mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
    if mode == 'train':
        x_train, y_train, x_valid, y_valid = mnist.train.images, mnist.train.labels, \
                                             mnist.validation.images, mnist.validation.labels
        return x_train, y_train, x_valid, y_valid
    elif mode == 'test':
        x_test, y_test = mnist.test.images, mnist.test.labels
    return x_test, y_test

# %%
x_train, y_train, x_valid, y_valid = load_data(mode='train')
print("Size of:")
print("- Training-set:\t\t{}".format(len(y_train)))
print("- Validation-set:\t{}".format(len(y_valid)))
# Out:
# WARNING:tensorflow:From <ipython-input-4-04a9792f2780>:8: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# Size of:
# - Training-set:		55000
# - Validation-set:	5000

# %%
x_train.shape
# Out:
# (55000, 784)

# %%
x_valid.shape
# Out:
# (5000, 784)

# %%
y_train.shape
# Out:
# (55000, 10)

# %%
def weight_variable(shape):
    """
    Create a weight variable with appropriate initialization
    :param name: weight name
    :param shape: weight shape
    :return: initialized weight variable
    """
    initer = tf.truncated_normal_initializer(stddev=0.01)
    return tf.get_variable('W',
                           dtype=tf.float32,
                           shape=shape,
                           initializer=initer)

def bias_variable(shape):
    """
    Create a bias variable with appropriate initialization
    :param name: bias variable name
    :param shape: bias variable shape
    :return: initialized bias variable
    """
    initial = tf.constant(0., shape=shape, dtype=tf.float32)
    return tf.get_variable('b',
                           dtype=tf.float32,
                           initializer=initial)

# %%
learning_rate = 0.001 # The optimization initial learning rate
epochs = 10           # Total number of training epochs
batch_size = 100      # Training batch size
display_freq = 100    # Frequency of displaying the training results
 
num_hidden_units = 128  # Number of hidden units of the RNN

# %%
def RNN(x, timesteps, num_hidden):
    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, num_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, num_input)
    x = tf.unstack(x, timesteps, 1)

    # Define lstm cells with tensorflow
    # Forward direction cell
    lstm_fw_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)
    # Backward direction cell
    

    # Get BiRNN cell output
    cell_outputs, _, _ = tf.nn.dynamic_rnn(lstm_fw_cell, x,
                                                 dtype=tf.float32)

    out = tf.layers.dense(inputs=cell_outputs, units=n_classes)

    # Linear activation, using rnn inner loop last output
#     return tf.matmul(outputs[-1], weights) + biases

    return out

# %%
x = tf.placeholder(tf.float32, shape=[None, timesteps, num_input], name='X')
y = tf.placeholder(tf.float32, shape=[None, n_classes], name='Y')


# W = weight_variable(shape=[2*num_hidden_units, n_classes])

# # create bias vector initialized as zero
# b = bias_variable(shape=[n_classes])

output_logits = RNN(x, timesteps, num_hidden_units)
# y_pred = tf.nn.softmax(output_logits)
# Out:
# -------------------------------------------------------------------
# ValueError                        Traceback (most recent call last)
# <ipython-input-17-1cff4e74de89> in <module>
#       8 # b = bias_variable(shape=[n_classes])
#       9
# ---> 10 output_logits = RNN(x, timesteps, num_hidden_units)
#      11 # y_pred = tf.nn.softmax(output_logits)
#
# <ipython-input-15-5f0ba8c80c02> in RNN(x, timesteps, num_hidden)
#      15     # Get BiRNN cell output
#      16     cell_outputs, _, _ = tf.nn.dynamic_rnn(lstm_fw_cell, x,
# ---> 17                                                  dtype=tf.float32)
#      18
#      19     out = tf.layers.dense(inputs=cell_outputs, units=n_classes)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in dynamic_rnn(cell, inputs, sequence_length, initial_state, dtype, parallel_iterations, swap_memory, time_major, scope)
#     669         swap_memory=swap_memory,
#     670         sequence_length=sequence_length,
# --> 671         dtype=dtype)
#     672
#     673     # Outputs of _dynamic_rnn_loop are always shaped [time, batch, depth].
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in _dynamic_rnn_loop(cell, inputs, initial_state, parallel_iterations, swap_memory, sequence_length, dtype)
#     736
#     737   inputs_got_shape = tuple(input_.get_shape().with_rank_at_least(3)
# --> 738                            for input_ in flat_input)
#     739
#     740   const_time_steps, const_batch_size = inputs_got_shape[0].as_list()[:2]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/rnn.py in <genexpr>(.0)
#     736
#     737   inputs_got_shape = tuple(input_.get_shape().with_rank_at_least(3)
# --> 738                            for input_ in flat_input)
#     739
#     740   const_time_steps, const_batch_size = inputs_got_shape[0].as_list()[:2]
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/tensor_shape.py in with_rank_at_least(self, rank)
#     938     """
#     939     if self.rank is not None and self.rank < rank:
# --> 940       raise ValueError("Shape %s must have rank at least %d" % (self, rank))
#     941     else:
#     942       return self
#
# ValueError: Shape (28, ?) must have rank at least 3

# %%
y_pred = tf.nn.softmax(output_logits)
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-13-9c20f567e818> in <module>
# ----> 1 y_pred = tf.nn.softmax(output_logits)
#
# NameError: name 'output_logits' is not defined

# %% [markdown]
# ## LSTM from keras

# %%
from random import random
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed

# create a sequence classification instance
def get_sequence(n_timesteps):
	# create a sequence of random numbers in [0,1]
	X = array([random() for _ in range(n_timesteps)])
	# calculate cut-off value to change class values
	limit = n_timesteps/4.0
	# determine the class outcome for each item in cumulative sequence
	y = array([0 if x < limit else 1 for x in cumsum(X)])
	# reshape input and output data to be suitable for LSTMs
	X = X.reshape(1, n_timesteps, 1)
	y = y.reshape(1, n_timesteps, 1)
	return X, y

# define problem properties
n_timesteps = 10
# define LSTM
model = Sequential()
model.add(LSTM(20, input_shape=(n_timesteps, 1), return_sequences=True))
model.add(TimeDistributed(Dense(1, activation='sigmoid')))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# train LSTM
for epoch in range(1000):
	# generate new random sequence
	X,y = get_sequence(n_timesteps)
	# fit model for one epoch on this sequence
	model.fit(X, y, epochs=1, batch_size=1, verbose=2)
# evaluate LSTM
X,y = get_sequence(n_timesteps)
yhat = model.predict_classes(X, verbose=0)
for i in range(n_timesteps):
	print('Expected:', y[0, i], 'Predicted', yhat[0, i])
# Out:
# WARNING:tensorflow:From /Users/ritwik7/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/1
#  - 3s - loss: 0.7075 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6881 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6948 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.7019 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.7046 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6972 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6940 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6944 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6898 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6930 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6874 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6881 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6850 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.6816 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.6733 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6805 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6794 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6881 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6617 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6821 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6707 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6712 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6585 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6555 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6505 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6489 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6763 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6279 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6404 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6374 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6726 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6968 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.6445 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6138 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6127 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5888 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5922 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6184 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6640 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.6099 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5577 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5912 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5504 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6187 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.7714 - acc: 0.1000
# Epoch 1/1
#  - 0s - loss: 0.5116 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5724 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6628 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.5616 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6024 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6004 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5993 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.6101 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.7363 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.4725 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.7162 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.5373 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5928 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5807 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5084 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5015 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4528 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4581 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5013 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4837 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3984 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5644 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4783 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5514 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4000 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3961 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4480 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3711 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4411 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6204 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 1.2600 - acc: 0.0000e+00
# Epoch 1/1
#  - 0s - loss: 0.4254 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4355 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4367 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.7693 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.7358 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.6467 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.5468 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5309 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5138 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5244 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4415 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4418 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5020 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6150 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4325 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3664 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.8310 - acc: 0.3000
# Epoch 1/1
#  - 0s - loss: 0.4309 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6099 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5096 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3629 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4255 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.6163 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 1.0706 - acc: 0.2000
# Epoch 1/1
#  - 0s - loss: 0.5950 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.5038 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4855 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4319 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.6485 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4844 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3665 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4909 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4257 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.5670 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.5653 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.6650 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4343 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3667 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4239 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4841 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4745 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3170 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5480 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.7034 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4740 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4110 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3544 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3965 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4596 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4589 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3560 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3381 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4458 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.5268 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.5268 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.7181 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.4450 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4393 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3711 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3265 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6321 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3962 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4331 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3152 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3710 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4256 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4998 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3352 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2995 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3564 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6163 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.4205 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.4182 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3500 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3535 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2964 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3493 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.7238 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3479 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3020 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4033 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3423 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.5974 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.4089 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3467 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4039 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.5763 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3382 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.5773 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3670 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3079 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.9543 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.2938 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3206 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3439 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4737 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3639 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3318 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3503 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4374 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3304 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3768 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3086 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3464 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3418 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3227 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3592 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2933 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3178 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3263 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3196 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3645 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6499 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.2823 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3774 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.6215 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.8657 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.3020 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4517 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3019 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3598 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.5150 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3514 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3858 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4145 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3468 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3065 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2931 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4021 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3454 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3049 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3076 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3427 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3099 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3169 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2947 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3107 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2806 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2981 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2867 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4635 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3031 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3288 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3141 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3823 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4026 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2860 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2987 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2833 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2622 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2609 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3141 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3312 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2874 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3196 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3215 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2808 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3228 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 1.9764 - acc: 0.4000
# Epoch 1/1
#  - 0s - loss: 0.2595 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3138 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2532 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4690 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2864 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2598 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2865 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3089 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2817 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3015 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3888 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3121 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2716 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3976 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2704 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3433 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2897 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2819 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4063 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3292 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2591 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3099 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3001 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2785 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2595 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2525 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.9435 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3152 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2878 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.7162 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.2862 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2596 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3394 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3321 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2572 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3181 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2931 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2802 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2353 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2521 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2424 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2857 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2477 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2740 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2477 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2473 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2344 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2851 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3401 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3815 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.7733 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.3006 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2872 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2347 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.7585 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.3193 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2631 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2935 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2924 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2680 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2995 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3274 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2712 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2848 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2668 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2919 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3076 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2974 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2671 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2485 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2535 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2924 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2710 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2936 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2778 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2598 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2625 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2523 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2491 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2229 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2579 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2550 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2696 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2374 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2474 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2424 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2099 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2181 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2428 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3054 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2449 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2423 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1956 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3249 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.7259 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.2446 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2579 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2414 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3014 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3349 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3267 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2509 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2769 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3406 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2662 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2538 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2380 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2734 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2877 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2405 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2701 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3374 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2611 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2365 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5838 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2890 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1895 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2257 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3040 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3709 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2275 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3208 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3440 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2339 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4736 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2297 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2219 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2227 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2092 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2214 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2180 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2675 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2514 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2166 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3225 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2197 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2522 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2179 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2536 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2150 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2252 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2155 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2160 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2340 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2326 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2222 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2158 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2080 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3610 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2346 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2639 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2771 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2073 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2052 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2174 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3448 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2054 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2927 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1825 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2664 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1967 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1716 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3167 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2823 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3014 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1930 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5882 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1945 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1966 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1594 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2214 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2677 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2705 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2241 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2663 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3089 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2502 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1984 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5645 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2515 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2086 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6459 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2320 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2535 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2103 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1926 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1872 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3288 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2360 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2879 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2113 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3812 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2738 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2197 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6220 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1899 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1944 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2968 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3192 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2271 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3800 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1901 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3750 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2327 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1700 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2051 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1882 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3420 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3541 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2417 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2421 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2186 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4974 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1777 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2011 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2674 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3151 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2041 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2009 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2186 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2770 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1935 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6791 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2406 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1937 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1826 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2798 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1875 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6209 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2141 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2010 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2161 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4196 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1754 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2126 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3353 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1806 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2071 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2323 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2328 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3794 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2215 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2689 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2292 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2132 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3865 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2711 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2434 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2954 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2876 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 1.8299 - acc: 0.5000
# Epoch 1/1
#  - 0s - loss: 0.1787 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2321 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2643 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2080 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2149 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1851 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2890 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2593 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2215 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1967 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1920 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2915 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3504 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3537 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2842 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1838 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1668 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1970 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2936 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1700 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2417 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2122 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1852 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3274 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1978 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1860 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1962 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1946 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2157 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2098 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1953 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2080 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2106 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1859 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1844 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2769 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1946 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3172 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1871 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1889 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1877 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2558 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2803 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1412 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1722 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.7106 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 1.2866 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.2220 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1576 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.9302 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.2020 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1685 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1701 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1738 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2456 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2098 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1921 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1793 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1986 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2523 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2591 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3740 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1868 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2186 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2892 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3755 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2118 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4465 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2741 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2583 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1815 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2068 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1877 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1944 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1816 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1852 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1898 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1839 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1690 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1764 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1729 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2644 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1442 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1905 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2351 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2278 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1418 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2150 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2975 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1600 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1584 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1778 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1948 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1386 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1479 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2479 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1616 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1619 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4247 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1684 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1948 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1320 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1672 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1473 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3267 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3397 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2223 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2078 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2015 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1312 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2340 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3703 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2605 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1764 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6209 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1706 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1641 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1562 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4915 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1601 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3062 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1650 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1643 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3906 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1737 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2145 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1785 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1519 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1511 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1574 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2646 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2927 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1689 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2271 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1576 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2246 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1841 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1524 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3119 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1343 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1700 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1365 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1672 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3191 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1746 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2730 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1514 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3717 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1447 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1307 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1788 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1571 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2556 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2735 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2420 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2445 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2112 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3259 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2422 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1396 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2000 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2248 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1458 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2034 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1396 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1313 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 1.6059 - acc: 0.6000
# Epoch 1/1
#  - 0s - loss: 0.1414 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2453 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1720 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4835 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1581 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6154 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3148 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1648 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1865 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2275 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2574 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1380 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1567 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2328 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1392 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1475 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1867 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1779 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2099 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2855 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2301 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2164 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1857 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1958 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1936 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1662 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.7798 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.1841 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1636 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2517 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3322 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1621 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1535 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1522 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2132 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2277 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2608 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1484 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1698 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1651 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2085 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4837 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1556 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2548 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4133 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1774 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1887 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1894 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1938 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3957 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3593 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1898 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2777 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4225 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1736 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2573 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1546 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1675 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1599 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1886 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1545 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1901 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2202 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1441 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.8556 - acc: 0.7000
# Epoch 1/1
#  - 0s - loss: 0.1633 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2971 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1882 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2259 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1956 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2280 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1933 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1871 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2471 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1353 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2683 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.6327 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1416 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3100 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1748 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1720 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1823 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1523 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1567 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1975 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1672 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1849 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1865 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1568 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1854 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1700 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1284 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1922 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1759 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1420 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1326 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1664 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1438 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1410 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1721 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.5118 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1199 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.6030 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1556 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1653 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1334 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1570 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5555 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.2304 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1265 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1324 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1792 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3207 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1784 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3769 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3028 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2461 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1606 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2533 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2402 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1612 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3644 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3094 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2236 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3407 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1477 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2331 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1380 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1703 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1313 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3857 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.3230 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1675 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1676 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1933 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1534 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2311 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1365 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1451 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1787 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2106 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1431 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1869 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2661 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1949 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3365 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1387 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1915 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1604 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1632 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1183 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1498 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1179 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1178 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1390 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2320 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1433 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4529 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1076 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3087 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3148 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1478 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1533 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1466 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1440 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1356 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2765 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1363 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3338 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1296 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2542 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2470 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1209 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1275 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1428 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1258 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1371 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1321 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1555 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3239 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1143 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1544 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.4633 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1228 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1805 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1255 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2497 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3346 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1213 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1996 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1708 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1358 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1980 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2724 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1989 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1350 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3078 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1827 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2256 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2012 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1150 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1497 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.3868 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1355 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2063 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1949 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1769 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1531 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1416 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1113 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1433 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1417 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2821 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2455 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1827 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2113 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1447 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1154 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1915 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1122 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1568 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1718 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1329 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1326 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1815 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1453 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1772 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1996 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1294 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2104 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1055 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2411 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1221 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1750 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1307 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1601 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1576 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2714 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1039 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1581 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1235 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2934 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2248 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1187 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1157 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1934 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2118 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2055 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2192 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1948 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1875 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1294 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.5216 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1830 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1151 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1202 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.4854 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1375 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1632 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1654 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2420 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1172 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1447 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1125 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1238 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1049 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1514 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1057 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2125 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1123 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1376 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1030 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1190 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1095 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1067 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1572 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2052 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1069 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1827 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1987 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1967 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2537 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1402 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1344 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2451 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1002 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1277 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1054 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1353 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1036 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1169 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1011 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1466 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1416 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1141 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1163 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1434 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1129 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1469 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1440 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2507 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2581 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1775 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2108 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2338 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1182 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1299 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1313 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1571 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3657 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1115 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1616 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1660 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2289 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1374 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1090 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1917 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.3733 - acc: 0.8000
# Epoch 1/1
#  - 0s - loss: 0.1132 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1066 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.0931 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1310 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1430 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.0986 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1067 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1835 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1186 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1334 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1116 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1004 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1021 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1360 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2047 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1024 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.0896 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2877 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1578 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.0892 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.2631 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.0955 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.0965 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1421 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.2496 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1035 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1029 - acc: 1.0000
# Epoch 1/1
#  - 0s - loss: 0.1896 - acc: 0.9000
# Epoch 1/1
#  - 0s - loss: 0.1007 - acc: 1.0000
# Expected: [0] Predicted [0]
# Expected: [0] Predicted [0]
# Expected: [0] Predicted [0]
# Expected: [1] Predicted [0]
# Expected: [1] Predicted [1]
# Expected: [1] Predicted [1]
# Expected: [1] Predicted [1]
# Expected: [1] Predicted [1]
# Expected: [1] Predicted [1]
# Expected: [1] Predicted [1]

# %%
timesteps
# Out:
# 29

# %%
neurons=8
pretraining=False

for num, subj_file_path in enumerate([subj_files_list[1]]):

    file_path  ="/Users/ritwik7/Dropbox (Personal)/Postdoc_UCL/DATA/rlab_incomplete_rewardSWB_code/by_RN/appdata/"+ subj_file_path
                
#     file_path = file_path + "/OddEvenPlays"
    file_path = file_path + "/OddEvenPlays/RandomizedPlays1"

    train_data_df= pd.read_csv(file_path+"/train_data.csv")
    test_data_df = pd.read_csv(file_path+"/test_data.csv")
    val_data_df = pd.read_csv(file_path+"/val_data.csv")
    
    
    
    train_X = train_data_df[['Safe','BigRisky','SmallRisky']].values
    train_y = train_data_df[['Choice']].values.astype(np.int32).reshape(-1,timesteps,outputs)

    test_X = test_data_df[['Safe','BigRisky','SmallRisky']].values
    test_y = test_data_df[['Choice']].values.astype(np.int32).reshape(-1,13,outputs)

    val_X = val_data_df[['Safe','BigRisky','SmallRisky']].values
    val_y = val_data_df[['Choice']].values.astype(np.int32).reshape(-1,16,outputs)
        
    scaler = MinMaxScaler(feature_range=(0, 1))  
    train_X = scaler.fit_transform(train_X[:,]).reshape(-1,timesteps,inputs)
    test_X = scaler.fit_transform(test_X).reshape(-1,13,inputs)
    val_X = scaler.fit_transform(val_X).reshape(-1,16,inputs)


    #####################
    test_X = np.concatenate((test_X,val_X),axis=1)
    test_y = np.concatenate((test_y,val_y),axis=1)


    train_X = np.concatenate((train_X,test_X),axis=0)
    train_y = np.concatenate((train_y,test_y),axis=0)

    test_X = train_X[int(0.8*train_X.shape[0]):,:,:]
    test_y = train_y[int(0.8*train_y.shape[0]):,:,:]

    train_X = train_X[0:int(0.8*train_X.shape[0]),:,:]
    train_y = train_y[0:int(0.8*train_y.shape[0]),:,:]
    ###########################
    
    
        
#     metric_out_df, prob_train, prob_test, prob_val = train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)
#     train_RNN(neurons,train_X,train_y,test_X,test_y,val_X,val_y)

# %%
train_X.shape
# Out:
# (235, 29, 3)

# %%
test_X.shape
# Out:
# (59, 29, 3)

# %%
from random import random
from numpy import array
from numpy import cumsum
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import TimeDistributed
from keras.models import load_model


# create a sequence classification instance
# def get_sequence(n_timesteps):
# 	# create a sequence of random numbers in [0,1]
# 	X = array([random() for _ in range(n_timesteps)])
# 	# calculate cut-off value to change class values
# 	limit = n_timesteps/4.0
# 	# determine the class outcome for each item in cumulative sequence
# 	y = array([0 if x < limit else 1 for x in cumsum(X)])
# 	# reshape input and output data to be suitable for LSTMs
# 	X = X.reshape(1, n_timesteps, 1)
# 	y = y.reshape(1, n_timesteps, 1)
# 	return X, y

# def training_data:
#     x = train_X
#     y = train_y
#     return x,y

es = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
# es = keras.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', min_delta=1)

mc =keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', verbose=1, save_best_only=True)
# mc =keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)



# define problem properties
n_timesteps = 29
# define LSTM
model = Sequential()
model.add(LSTM(neurons, input_shape=(n_timesteps, inputs), return_sequences=True))
model.add(TimeDistributed(Dense(1, activation='sigmoid')))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# train LSTM
# for epoch in range(100):
# 	# generate new random sequence
# 	X,y = get_sequence(n_timesteps)
#     x,y = training_data(train_X,train_y)

x,y = train_X,train_y


# 	# fit model for one epoch on this sequence
#     model.fit(x, y, epochs=1, batch_size=1, verbose=2)
history=  model.fit(x, y, epochs=1000, batch_size=32, verbose=2, validation_split = 0.2,callbacks=[es,mc])



# # evaluate LSTM
# X,y = get_sequence(n_timesteps)
# yhat = model.predict_classes(X, verbose=0)
# for i in range(n_timesteps):
# 	print('Expected:', y[0, i], 'Predicted', yhat[0, i])


# load the saved model
saved_model = load_model('best_model.h5')
# evaluate the model
train_loss, train_acc = saved_model.evaluate(train_X, train_y, verbose=0)
test_loss, test_acc = saved_model.evaluate(test_X, test_y, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))

# yhat = model.predict_classes(test_X, verbose=0)
# Out:
# Train on 188 samples, validate on 47 samples
# Epoch 1/1000
#  - 3s - loss: 0.7665 - acc: 0.2447 - val_loss: 0.7585 - val_acc: 0.2370
#
# Epoch 00001: val_loss improved from inf to 0.75848, saving model to best_model.h5
# Epoch 2/1000
#  - 0s - loss: 0.7491 - acc: 0.2454 - val_loss: 0.7407 - val_acc: 0.2392
#
# Epoch 00002: val_loss improved from 0.75848 to 0.74066, saving model to best_model.h5
# Epoch 3/1000
#  - 0s - loss: 0.7324 - acc: 0.2498 - val_loss: 0.7241 - val_acc: 0.2480
#
# Epoch 00003: val_loss improved from 0.74066 to 0.72409, saving model to best_model.h5
# Epoch 4/1000
#  - 0s - loss: 0.7168 - acc: 0.2595 - val_loss: 0.7086 - val_acc: 0.2876
#
# Epoch 00004: val_loss improved from 0.72409 to 0.70861, saving model to best_model.h5
# Epoch 5/1000
#  - 0s - loss: 0.7026 - acc: 0.3287 - val_loss: 0.6939 - val_acc: 0.4615
#
# Epoch 00005: val_loss improved from 0.70861 to 0.69387, saving model to best_model.h5
# Epoch 6/1000
#  - 0s - loss: 0.6884 - acc: 0.5967 - val_loss: 0.6799 - val_acc: 0.7351
#
# Epoch 00006: val_loss improved from 0.69387 to 0.67988, saving model to best_model.h5
# Epoch 7/1000
#  - 0s - loss: 0.6756 - acc: 0.7397 - val_loss: 0.6660 - val_acc: 0.7652
#
# Epoch 00007: val_loss improved from 0.67988 to 0.66604, saving model to best_model.h5
# Epoch 8/1000
#  - 0s - loss: 0.6619 - acc: 0.7555 - val_loss: 0.6526 - val_acc: 0.7652
#
# Epoch 00008: val_loss improved from 0.66604 to 0.65262, saving model to best_model.h5
# Epoch 9/1000
#  - 0s - loss: 0.6498 - acc: 0.7555 - val_loss: 0.6390 - val_acc: 0.7652
#
# Epoch 00009: val_loss improved from 0.65262 to 0.63899, saving model to best_model.h5
# Epoch 10/1000
#  - 0s - loss: 0.6368 - acc: 0.7555 - val_loss: 0.6258 - val_acc: 0.7652
#
# Epoch 00010: val_loss improved from 0.63899 to 0.62580, saving model to best_model.h5
# Epoch 11/1000
#  - 0s - loss: 0.6244 - acc: 0.7555 - val_loss: 0.6130 - val_acc: 0.7652
#
# Epoch 00011: val_loss improved from 0.62580 to 0.61302, saving model to best_model.h5
# Epoch 12/1000
#  - 0s - loss: 0.6125 - acc: 0.7555 - val_loss: 0.6008 - val_acc: 0.7652
#
# Epoch 00012: val_loss improved from 0.61302 to 0.60083, saving model to best_model.h5
# Epoch 13/1000
#  - 0s - loss: 0.6014 - acc: 0.7555 - val_loss: 0.5896 - val_acc: 0.7652
#
# Epoch 00013: val_loss improved from 0.60083 to 0.58961, saving model to best_model.h5
# Epoch 14/1000
#  - 0s - loss: 0.5914 - acc: 0.7555 - val_loss: 0.5797 - val_acc: 0.7652
#
# Epoch 00014: val_loss improved from 0.58961 to 0.57968, saving model to best_model.h5
# Epoch 15/1000
#  - 0s - loss: 0.5827 - acc: 0.7555 - val_loss: 0.5714 - val_acc: 0.7652
#
# Epoch 00015: val_loss improved from 0.57968 to 0.57143, saving model to best_model.h5
# Epoch 16/1000
#  - 0s - loss: 0.5755 - acc: 0.7555 - val_loss: 0.5651 - val_acc: 0.7652
#
# Epoch 00016: val_loss improved from 0.57143 to 0.56512, saving model to best_model.h5
# Epoch 17/1000
#  - 0s - loss: 0.5710 - acc: 0.7555 - val_loss: 0.5603 - val_acc: 0.7652
#
# Epoch 00017: val_loss improved from 0.56512 to 0.56034, saving model to best_model.h5
# Epoch 18/1000
#  - 0s - loss: 0.5675 - acc: 0.7555 - val_loss: 0.5572 - val_acc: 0.7652
#
# Epoch 00018: val_loss improved from 0.56034 to 0.55723, saving model to best_model.h5
# Epoch 19/1000
#  - 0s - loss: 0.5655 - acc: 0.7555 - val_loss: 0.5553 - val_acc: 0.7652
#
# Epoch 00019: val_loss improved from 0.55723 to 0.55531, saving model to best_model.h5
# Epoch 20/1000
#  - 0s - loss: 0.5649 - acc: 0.7555 - val_loss: 0.5541 - val_acc: 0.7652
#
# Epoch 00020: val_loss improved from 0.55531 to 0.55406, saving model to best_model.h5
# Epoch 21/1000
#  - 0s - loss: 0.5639 - acc: 0.7555 - val_loss: 0.5533 - val_acc: 0.7652
#
# Epoch 00021: val_loss improved from 0.55406 to 0.55334, saving model to best_model.h5
# Epoch 22/1000
#  - 0s - loss: 0.5634 - acc: 0.7555 - val_loss: 0.5528 - val_acc: 0.7652
#
# Epoch 00022: val_loss improved from 0.55334 to 0.55277, saving model to best_model.h5
# Epoch 23/1000
#  - 0s - loss: 0.5630 - acc: 0.7555 - val_loss: 0.5523 - val_acc: 0.7652
#
# Epoch 00023: val_loss improved from 0.55277 to 0.55232, saving model to best_model.h5
# Epoch 24/1000
#  - 0s - loss: 0.5627 - acc: 0.7555 - val_loss: 0.5518 - val_acc: 0.7652
#
# Epoch 00024: val_loss improved from 0.55232 to 0.55183, saving model to best_model.h5
# Epoch 25/1000
#  - 0s - loss: 0.5623 - acc: 0.7555 - val_loss: 0.5514 - val_acc: 0.7652
#
# Epoch 00025: val_loss improved from 0.55183 to 0.55140, saving model to best_model.h5
# Epoch 26/1000
#  - 0s - loss: 0.5619 - acc: 0.7555 - val_loss: 0.5510 - val_acc: 0.7652
#
# Epoch 00026: val_loss improved from 0.55140 to 0.55096, saving model to best_model.h5
# Epoch 27/1000
#  - 0s - loss: 0.5615 - acc: 0.7555 - val_loss: 0.5506 - val_acc: 0.7652
#
# Epoch 00027: val_loss improved from 0.55096 to 0.55059, saving model to best_model.h5
# Epoch 28/1000
#  - 0s - loss: 0.5612 - acc: 0.7555 - val_loss: 0.5502 - val_acc: 0.7652
#
# Epoch 00028: val_loss improved from 0.55059 to 0.55021, saving model to best_model.h5
# Epoch 29/1000
#  - 0s - loss: 0.5608 - acc: 0.7555 - val_loss: 0.5498 - val_acc: 0.7652
#
# Epoch 00029: val_loss improved from 0.55021 to 0.54980, saving model to best_model.h5
# Epoch 30/1000
#  - 0s - loss: 0.5605 - acc: 0.7555 - val_loss: 0.5494 - val_acc: 0.7652
#
# Epoch 00030: val_loss improved from 0.54980 to 0.54939, saving model to best_model.h5
# Epoch 31/1000
#  - 0s - loss: 0.5602 - acc: 0.7555 - val_loss: 0.5490 - val_acc: 0.7652
#
# Epoch 00031: val_loss improved from 0.54939 to 0.54896, saving model to best_model.h5
# Epoch 32/1000
#  - 0s - loss: 0.5598 - acc: 0.7555 - val_loss: 0.5486 - val_acc: 0.7652
#
# Epoch 00032: val_loss improved from 0.54896 to 0.54859, saving model to best_model.h5
# Epoch 33/1000
#  - 0s - loss: 0.5595 - acc: 0.7555 - val_loss: 0.5482 - val_acc: 0.7652
#
# Epoch 00033: val_loss improved from 0.54859 to 0.54821, saving model to best_model.h5
# Epoch 34/1000
#  - 0s - loss: 0.5591 - acc: 0.7555 - val_loss: 0.5478 - val_acc: 0.7652
#
# Epoch 00034: val_loss improved from 0.54821 to 0.54782, saving model to best_model.h5
# Epoch 35/1000
#  - 0s - loss: 0.5588 - acc: 0.7555 - val_loss: 0.5474 - val_acc: 0.7652
#
# Epoch 00035: val_loss improved from 0.54782 to 0.54745, saving model to best_model.h5
# Epoch 36/1000
#  - 0s - loss: 0.5585 - acc: 0.7555 - val_loss: 0.5470 - val_acc: 0.7652
#
# Epoch 00036: val_loss improved from 0.54745 to 0.54703, saving model to best_model.h5
# Epoch 37/1000
#  - 0s - loss: 0.5582 - acc: 0.7555 - val_loss: 0.5467 - val_acc: 0.7652
#
# Epoch 00037: val_loss improved from 0.54703 to 0.54666, saving model to best_model.h5
# Epoch 38/1000
#  - 0s - loss: 0.5578 - acc: 0.7555 - val_loss: 0.5463 - val_acc: 0.7652
#
# Epoch 00038: val_loss improved from 0.54666 to 0.54627, saving model to best_model.h5
# Epoch 39/1000
#  - 0s - loss: 0.5575 - acc: 0.7555 - val_loss: 0.5459 - val_acc: 0.7652
#
# Epoch 00039: val_loss improved from 0.54627 to 0.54591, saving model to best_model.h5
# Epoch 40/1000
#  - 0s - loss: 0.5572 - acc: 0.7555 - val_loss: 0.5455 - val_acc: 0.7652
#
# Epoch 00040: val_loss improved from 0.54591 to 0.54550, saving model to best_model.h5
# Epoch 41/1000
#  - 0s - loss: 0.5569 - acc: 0.7555 - val_loss: 0.5451 - val_acc: 0.7652
#
# Epoch 00041: val_loss improved from 0.54550 to 0.54514, saving model to best_model.h5
# Epoch 42/1000
#  - 0s - loss: 0.5565 - acc: 0.7555 - val_loss: 0.5448 - val_acc: 0.7652
#
# Epoch 00042: val_loss improved from 0.54514 to 0.54477, saving model to best_model.h5
# Epoch 43/1000
#  - 0s - loss: 0.5562 - acc: 0.7555 - val_loss: 0.5443 - val_acc: 0.7652
#
# Epoch 00043: val_loss improved from 0.54477 to 0.54435, saving model to best_model.h5
# Epoch 44/1000
#  - 0s - loss: 0.5559 - acc: 0.7555 - val_loss: 0.5440 - val_acc: 0.7652
#
# Epoch 00044: val_loss improved from 0.54435 to 0.54396, saving model to best_model.h5
# Epoch 45/1000
#  - 0s - loss: 0.5556 - acc: 0.7555 - val_loss: 0.5436 - val_acc: 0.7652
#
# Epoch 00045: val_loss improved from 0.54396 to 0.54361, saving model to best_model.h5
# Epoch 46/1000
#  - 0s - loss: 0.5553 - acc: 0.7555 - val_loss: 0.5433 - val_acc: 0.7652
#
# Epoch 00046: val_loss improved from 0.54361 to 0.54327, saving model to best_model.h5
# Epoch 47/1000
#  - 0s - loss: 0.5550 - acc: 0.7555 - val_loss: 0.5429 - val_acc: 0.7652
#
# Epoch 00047: val_loss improved from 0.54327 to 0.54287, saving model to best_model.h5
# Epoch 48/1000
#  - 0s - loss: 0.5546 - acc: 0.7555 - val_loss: 0.5425 - val_acc: 0.7652
#
# Epoch 00048: val_loss improved from 0.54287 to 0.54254, saving model to best_model.h5
# Epoch 49/1000
#  - 0s - loss: 0.5543 - acc: 0.7555 - val_loss: 0.5422 - val_acc: 0.7652
#
# Epoch 00049: val_loss improved from 0.54254 to 0.54219, saving model to best_model.h5
# Epoch 50/1000
#  - 0s - loss: 0.5540 - acc: 0.7555 - val_loss: 0.5419 - val_acc: 0.7652
#
# Epoch 00050: val_loss improved from 0.54219 to 0.54187, saving model to best_model.h5
# Epoch 51/1000
#  - 0s - loss: 0.5537 - acc: 0.7555 - val_loss: 0.5415 - val_acc: 0.7652
#
# Epoch 00051: val_loss improved from 0.54187 to 0.54152, saving model to best_model.h5
# Epoch 52/1000
#  - 0s - loss: 0.5534 - acc: 0.7555 - val_loss: 0.5412 - val_acc: 0.7652
#
# Epoch 00052: val_loss improved from 0.54152 to 0.54118, saving model to best_model.h5
# Epoch 53/1000
#  - 0s - loss: 0.5532 - acc: 0.7555 - val_loss: 0.5409 - val_acc: 0.7652
#
# Epoch 00053: val_loss improved from 0.54118 to 0.54090, saving model to best_model.h5
# Epoch 54/1000
#  - 0s - loss: 0.5527 - acc: 0.7555 - val_loss: 0.5405 - val_acc: 0.7652
#
# Epoch 00054: val_loss improved from 0.54090 to 0.54049, saving model to best_model.h5
# Epoch 55/1000
#  - 0s - loss: 0.5524 - acc: 0.7555 - val_loss: 0.5401 - val_acc: 0.7652
#
# Epoch 00055: val_loss improved from 0.54049 to 0.54011, saving model to best_model.h5
# Epoch 56/1000
#  - 0s - loss: 0.5522 - acc: 0.7555 - val_loss: 0.5397 - val_acc: 0.7652
#
# Epoch 00056: val_loss improved from 0.54011 to 0.53971, saving model to best_model.h5
# Epoch 57/1000
#  - 0s - loss: 0.5518 - acc: 0.7555 - val_loss: 0.5394 - val_acc: 0.7652
#
# Epoch 00057: val_loss improved from 0.53971 to 0.53936, saving model to best_model.h5
# Epoch 58/1000
#  - 0s - loss: 0.5515 - acc: 0.7555 - val_loss: 0.5390 - val_acc: 0.7652
#
# Epoch 00058: val_loss improved from 0.53936 to 0.53900, saving model to best_model.h5
# Epoch 59/1000
#  - 0s - loss: 0.5512 - acc: 0.7555 - val_loss: 0.5386 - val_acc: 0.7652
#
# Epoch 00059: val_loss improved from 0.53900 to 0.53864, saving model to best_model.h5
# Epoch 60/1000
#  - 0s - loss: 0.5509 - acc: 0.7555 - val_loss: 0.5384 - val_acc: 0.7652
#
# Epoch 00060: val_loss improved from 0.53864 to 0.53838, saving model to best_model.h5
# Epoch 61/1000
#  - 0s - loss: 0.5505 - acc: 0.7555 - val_loss: 0.5380 - val_acc: 0.7652
#
# Epoch 00061: val_loss improved from 0.53838 to 0.53800, saving model to best_model.h5
# Epoch 62/1000
#  - 0s - loss: 0.5502 - acc: 0.7555 - val_loss: 0.5376 - val_acc: 0.7652
#
# Epoch 00062: val_loss improved from 0.53800 to 0.53762, saving model to best_model.h5
# Epoch 63/1000
#  - 0s - loss: 0.5499 - acc: 0.7555 - val_loss: 0.5372 - val_acc: 0.7652
#
# Epoch 00063: val_loss improved from 0.53762 to 0.53719, saving model to best_model.h5
# Epoch 64/1000
#  - 0s - loss: 0.5495 - acc: 0.7555 - val_loss: 0.5368 - val_acc: 0.7652
#
# Epoch 00064: val_loss improved from 0.53719 to 0.53682, saving model to best_model.h5
# Epoch 65/1000
#  - 0s - loss: 0.5492 - acc: 0.7555 - val_loss: 0.5364 - val_acc: 0.7652
#
# Epoch 00065: val_loss improved from 0.53682 to 0.53643, saving model to best_model.h5
# Epoch 66/1000
#  - 0s - loss: 0.5489 - acc: 0.7555 - val_loss: 0.5362 - val_acc: 0.7652
#
# Epoch 00066: val_loss improved from 0.53643 to 0.53615, saving model to best_model.h5
# Epoch 67/1000
#  - 0s - loss: 0.5486 - acc: 0.7555 - val_loss: 0.5357 - val_acc: 0.7652
#
# Epoch 00067: val_loss improved from 0.53615 to 0.53571, saving model to best_model.h5
# Epoch 68/1000
#  - 0s - loss: 0.5481 - acc: 0.7555 - val_loss: 0.5354 - val_acc: 0.7652
#
# Epoch 00068: val_loss improved from 0.53571 to 0.53539, saving model to best_model.h5
# Epoch 69/1000
#  - 0s - loss: 0.5477 - acc: 0.7555 - val_loss: 0.5350 - val_acc: 0.7652
#
# Epoch 00069: val_loss improved from 0.53539 to 0.53499, saving model to best_model.h5
# Epoch 70/1000
#  - 0s - loss: 0.5474 - acc: 0.7555 - val_loss: 0.5346 - val_acc: 0.7652
#
# Epoch 00070: val_loss improved from 0.53499 to 0.53460, saving model to best_model.h5
# Epoch 71/1000
#  - 0s - loss: 0.5470 - acc: 0.7555 - val_loss: 0.5342 - val_acc: 0.7652
#
# Epoch 00071: val_loss improved from 0.53460 to 0.53419, saving model to best_model.h5
# Epoch 72/1000
#  - 0s - loss: 0.5466 - acc: 0.7555 - val_loss: 0.5338 - val_acc: 0.7652
#
# Epoch 00072: val_loss improved from 0.53419 to 0.53375, saving model to best_model.h5
# Epoch 73/1000
#  - 0s - loss: 0.5463 - acc: 0.7555 - val_loss: 0.5333 - val_acc: 0.7652
#
# Epoch 00073: val_loss improved from 0.53375 to 0.53329, saving model to best_model.h5
# Epoch 74/1000
#  - 0s - loss: 0.5458 - acc: 0.7555 - val_loss: 0.5329 - val_acc: 0.7652
#
# Epoch 00074: val_loss improved from 0.53329 to 0.53291, saving model to best_model.h5
# Epoch 75/1000
#  - 0s - loss: 0.5454 - acc: 0.7555 - val_loss: 0.5325 - val_acc: 0.7652
#
# Epoch 00075: val_loss improved from 0.53291 to 0.53254, saving model to best_model.h5
# Epoch 76/1000
#  - 0s - loss: 0.5450 - acc: 0.7555 - val_loss: 0.5321 - val_acc: 0.7652
#
# Epoch 00076: val_loss improved from 0.53254 to 0.53209, saving model to best_model.h5
# Epoch 77/1000
#  - 0s - loss: 0.5446 - acc: 0.7555 - val_loss: 0.5316 - val_acc: 0.7652
#
# Epoch 00077: val_loss improved from 0.53209 to 0.53160, saving model to best_model.h5
# Epoch 78/1000
#  - 0s - loss: 0.5441 - acc: 0.7555 - val_loss: 0.5311 - val_acc: 0.7652
#
# Epoch 00078: val_loss improved from 0.53160 to 0.53113, saving model to best_model.h5
# Epoch 79/1000
#  - 0s - loss: 0.5438 - acc: 0.7555 - val_loss: 0.5306 - val_acc: 0.7652
#
# Epoch 00079: val_loss improved from 0.53113 to 0.53056, saving model to best_model.h5
# Epoch 80/1000
#  - 0s - loss: 0.5432 - acc: 0.7555 - val_loss: 0.5301 - val_acc: 0.7652
#
# Epoch 00080: val_loss improved from 0.53056 to 0.53015, saving model to best_model.h5
# Epoch 81/1000
#  - 0s - loss: 0.5427 - acc: 0.7555 - val_loss: 0.5297 - val_acc: 0.7652
#
# Epoch 00081: val_loss improved from 0.53015 to 0.52966, saving model to best_model.h5
# Epoch 82/1000
#  - 0s - loss: 0.5422 - acc: 0.7555 - val_loss: 0.5291 - val_acc: 0.7652
#
# Epoch 00082: val_loss improved from 0.52966 to 0.52913, saving model to best_model.h5
# Epoch 83/1000
#  - 0s - loss: 0.5418 - acc: 0.7555 - val_loss: 0.5285 - val_acc: 0.7652
#
# Epoch 00083: val_loss improved from 0.52913 to 0.52854, saving model to best_model.h5
# Epoch 84/1000
#  - 0s - loss: 0.5412 - acc: 0.7555 - val_loss: 0.5280 - val_acc: 0.7652
#
# Epoch 00084: val_loss improved from 0.52854 to 0.52801, saving model to best_model.h5
# Epoch 85/1000
#  - 0s - loss: 0.5407 - acc: 0.7555 - val_loss: 0.5275 - val_acc: 0.7652
#
# Epoch 00085: val_loss improved from 0.52801 to 0.52746, saving model to best_model.h5
# Epoch 86/1000
#  - 0s - loss: 0.5401 - acc: 0.7555 - val_loss: 0.5270 - val_acc: 0.7652
#
# Epoch 00086: val_loss improved from 0.52746 to 0.52697, saving model to best_model.h5
# Epoch 87/1000
#  - 0s - loss: 0.5396 - acc: 0.7555 - val_loss: 0.5264 - val_acc: 0.7652
#
# Epoch 00087: val_loss improved from 0.52697 to 0.52640, saving model to best_model.h5
# Epoch 88/1000
#  - 0s - loss: 0.5391 - acc: 0.7555 - val_loss: 0.5259 - val_acc: 0.7652
#
# Epoch 00088: val_loss improved from 0.52640 to 0.52590, saving model to best_model.h5
# Epoch 89/1000
#  - 0s - loss: 0.5385 - acc: 0.7555 - val_loss: 0.5253 - val_acc: 0.7652
#
# Epoch 00089: val_loss improved from 0.52590 to 0.52532, saving model to best_model.h5
# Epoch 90/1000
#  - 0s - loss: 0.5379 - acc: 0.7555 - val_loss: 0.5248 - val_acc: 0.7652
#
# Epoch 00090: val_loss improved from 0.52532 to 0.52479, saving model to best_model.h5
# Epoch 91/1000
#  - 0s - loss: 0.5374 - acc: 0.7555 - val_loss: 0.5242 - val_acc: 0.7652
#
# Epoch 00091: val_loss improved from 0.52479 to 0.52424, saving model to best_model.h5
# Epoch 92/1000
#  - 0s - loss: 0.5368 - acc: 0.7555 - val_loss: 0.5236 - val_acc: 0.7652
#
# Epoch 00092: val_loss improved from 0.52424 to 0.52358, saving model to best_model.h5
# Epoch 93/1000
#  - 0s - loss: 0.5363 - acc: 0.7555 - val_loss: 0.5230 - val_acc: 0.7652
#
# Epoch 00093: val_loss improved from 0.52358 to 0.52300, saving model to best_model.h5
# Epoch 94/1000
#  - 0s - loss: 0.5358 - acc: 0.7555 - val_loss: 0.5225 - val_acc: 0.7652
#
# Epoch 00094: val_loss improved from 0.52300 to 0.52252, saving model to best_model.h5
# Epoch 95/1000
#  - 0s - loss: 0.5354 - acc: 0.7555 - val_loss: 0.5221 - val_acc: 0.7652
#
# Epoch 00095: val_loss improved from 0.52252 to 0.52208, saving model to best_model.h5
# Epoch 96/1000
#  - 0s - loss: 0.5350 - acc: 0.7555 - val_loss: 0.5216 - val_acc: 0.7652
#
# Epoch 00096: val_loss improved from 0.52208 to 0.52157, saving model to best_model.h5
# Epoch 97/1000
#  - 0s - loss: 0.5345 - acc: 0.7555 - val_loss: 0.5211 - val_acc: 0.7652
#
# Epoch 00097: val_loss improved from 0.52157 to 0.52113, saving model to best_model.h5
# Epoch 98/1000
#  - 0s - loss: 0.5340 - acc: 0.7555 - val_loss: 0.5207 - val_acc: 0.7652
#
# Epoch 00098: val_loss improved from 0.52113 to 0.52069, saving model to best_model.h5
# Epoch 99/1000
#  - 0s - loss: 0.5336 - acc: 0.7555 - val_loss: 0.5204 - val_acc: 0.7652
#
# Epoch 00099: val_loss improved from 0.52069 to 0.52037, saving model to best_model.h5
# Epoch 100/1000
#  - 0s - loss: 0.5332 - acc: 0.7555 - val_loss: 0.5200 - val_acc: 0.7652
#
# Epoch 00100: val_loss improved from 0.52037 to 0.52003, saving model to best_model.h5
# Epoch 101/1000
#  - 0s - loss: 0.5328 - acc: 0.7555 - val_loss: 0.5196 - val_acc: 0.7652
#
# Epoch 00101: val_loss improved from 0.52003 to 0.51961, saving model to best_model.h5
# Epoch 102/1000
#  - 0s - loss: 0.5323 - acc: 0.7555 - val_loss: 0.5191 - val_acc: 0.7652
#
# Epoch 00102: val_loss improved from 0.51961 to 0.51914, saving model to best_model.h5
# Epoch 103/1000
#  - 0s - loss: 0.5320 - acc: 0.7555 - val_loss: 0.5187 - val_acc: 0.7652
#
# Epoch 00103: val_loss improved from 0.51914 to 0.51870, saving model to best_model.h5
# Epoch 104/1000
#  - 0s - loss: 0.5316 - acc: 0.7555 - val_loss: 0.5183 - val_acc: 0.7652
#
# Epoch 00104: val_loss improved from 0.51870 to 0.51830, saving model to best_model.h5
# Epoch 105/1000
#  - 0s - loss: 0.5312 - acc: 0.7555 - val_loss: 0.5178 - val_acc: 0.7652
#
# Epoch 00105: val_loss improved from 0.51830 to 0.51779, saving model to best_model.h5
# Epoch 106/1000
#  - 0s - loss: 0.5308 - acc: 0.7555 - val_loss: 0.5173 - val_acc: 0.7652
#
# Epoch 00106: val_loss improved from 0.51779 to 0.51735, saving model to best_model.h5
# Epoch 107/1000
#  - 0s - loss: 0.5304 - acc: 0.7555 - val_loss: 0.5170 - val_acc: 0.7652
#
# Epoch 00107: val_loss improved from 0.51735 to 0.51702, saving model to best_model.h5
# Epoch 108/1000
#  - 0s - loss: 0.5301 - acc: 0.7555 - val_loss: 0.5167 - val_acc: 0.7652
#
# Epoch 00108: val_loss improved from 0.51702 to 0.51674, saving model to best_model.h5
# Epoch 109/1000
#  - 0s - loss: 0.5297 - acc: 0.7555 - val_loss: 0.5162 - val_acc: 0.7652
#
# Epoch 00109: val_loss improved from 0.51674 to 0.51621, saving model to best_model.h5
# Epoch 110/1000
#  - 0s - loss: 0.5293 - acc: 0.7555 - val_loss: 0.5159 - val_acc: 0.7652
#
# Epoch 00110: val_loss improved from 0.51621 to 0.51585, saving model to best_model.h5
# Epoch 111/1000
#  - 0s - loss: 0.5289 - acc: 0.7555 - val_loss: 0.5154 - val_acc: 0.7652
#
# Epoch 00111: val_loss improved from 0.51585 to 0.51545, saving model to best_model.h5
# Epoch 112/1000
#  - 0s - loss: 0.5286 - acc: 0.7555 - val_loss: 0.5151 - val_acc: 0.7652
#
# Epoch 00112: val_loss improved from 0.51545 to 0.51508, saving model to best_model.h5
# Epoch 113/1000
#  - 0s - loss: 0.5282 - acc: 0.7555 - val_loss: 0.5148 - val_acc: 0.7652
#
# Epoch 00113: val_loss improved from 0.51508 to 0.51475, saving model to best_model.h5
# Epoch 114/1000
#  - 0s - loss: 0.5278 - acc: 0.7555 - val_loss: 0.5144 - val_acc: 0.7652
#
# Epoch 00114: val_loss improved from 0.51475 to 0.51442, saving model to best_model.h5
# Epoch 115/1000
#  - 0s - loss: 0.5275 - acc: 0.7555 - val_loss: 0.5140 - val_acc: 0.7652
#
# Epoch 00115: val_loss improved from 0.51442 to 0.51403, saving model to best_model.h5
# Epoch 116/1000
#  - 0s - loss: 0.5272 - acc: 0.7555 - val_loss: 0.5136 - val_acc: 0.7652
#
# Epoch 00116: val_loss improved from 0.51403 to 0.51357, saving model to best_model.h5
# Epoch 117/1000
#  - 0s - loss: 0.5268 - acc: 0.7555 - val_loss: 0.5132 - val_acc: 0.7652
#
# Epoch 00117: val_loss improved from 0.51357 to 0.51323, saving model to best_model.h5
# Epoch 118/1000
#  - 0s - loss: 0.5264 - acc: 0.7555 - val_loss: 0.5128 - val_acc: 0.7652
#
# Epoch 00118: val_loss improved from 0.51323 to 0.51279, saving model to best_model.h5
# Epoch 119/1000
#  - 0s - loss: 0.5260 - acc: 0.7555 - val_loss: 0.5125 - val_acc: 0.7652
#
# Epoch 00119: val_loss improved from 0.51279 to 0.51251, saving model to best_model.h5
# Epoch 120/1000
#  - 0s - loss: 0.5256 - acc: 0.7555 - val_loss: 0.5121 - val_acc: 0.7652
#
# Epoch 00120: val_loss improved from 0.51251 to 0.51209, saving model to best_model.h5
# Epoch 121/1000
#  - 0s - loss: 0.5253 - acc: 0.7555 - val_loss: 0.5117 - val_acc: 0.7652
#
# Epoch 00121: val_loss improved from 0.51209 to 0.51170, saving model to best_model.h5
# Epoch 122/1000
#  - 0s - loss: 0.5249 - acc: 0.7555 - val_loss: 0.5114 - val_acc: 0.7652
#
# Epoch 00122: val_loss improved from 0.51170 to 0.51137, saving model to best_model.h5
# Epoch 123/1000
#  - 0s - loss: 0.5246 - acc: 0.7555 - val_loss: 0.5109 - val_acc: 0.7652
#
# Epoch 00123: val_loss improved from 0.51137 to 0.51090, saving model to best_model.h5
# Epoch 124/1000
#  - 0s - loss: 0.5243 - acc: 0.7555 - val_loss: 0.5104 - val_acc: 0.7652
#
# Epoch 00124: val_loss improved from 0.51090 to 0.51043, saving model to best_model.h5
# Epoch 125/1000
#  - 0s - loss: 0.5238 - acc: 0.7555 - val_loss: 0.5101 - val_acc: 0.7652
#
# Epoch 00125: val_loss improved from 0.51043 to 0.51006, saving model to best_model.h5
# Epoch 126/1000
#  - 0s - loss: 0.5236 - acc: 0.7555 - val_loss: 0.5099 - val_acc: 0.7652
#
# Epoch 00126: val_loss improved from 0.51006 to 0.50995, saving model to best_model.h5
# Epoch 127/1000
#  - 0s - loss: 0.5232 - acc: 0.7555 - val_loss: 0.5095 - val_acc: 0.7652
#
# Epoch 00127: val_loss improved from 0.50995 to 0.50952, saving model to best_model.h5
# Epoch 128/1000
#  - 0s - loss: 0.5228 - acc: 0.7555 - val_loss: 0.5092 - val_acc: 0.7652
#
# Epoch 00128: val_loss improved from 0.50952 to 0.50920, saving model to best_model.h5
# Epoch 129/1000
#  - 0s - loss: 0.5225 - acc: 0.7555 - val_loss: 0.5088 - val_acc: 0.7652
#
# Epoch 00129: val_loss improved from 0.50920 to 0.50882, saving model to best_model.h5
# Epoch 130/1000
#  - 0s - loss: 0.5222 - acc: 0.7555 - val_loss: 0.5085 - val_acc: 0.7652
#
# Epoch 00130: val_loss improved from 0.50882 to 0.50851, saving model to best_model.h5
# Epoch 131/1000
#  - 0s - loss: 0.5220 - acc: 0.7555 - val_loss: 0.5082 - val_acc: 0.7652
#
# Epoch 00131: val_loss improved from 0.50851 to 0.50821, saving model to best_model.h5
# Epoch 132/1000
#  - 0s - loss: 0.5215 - acc: 0.7555 - val_loss: 0.5078 - val_acc: 0.7652
#
# Epoch 00132: val_loss improved from 0.50821 to 0.50775, saving model to best_model.h5
# Epoch 133/1000
#  - 0s - loss: 0.5214 - acc: 0.7555 - val_loss: 0.5072 - val_acc: 0.7652
#
# Epoch 00133: val_loss improved from 0.50775 to 0.50717, saving model to best_model.h5
# Epoch 134/1000
#  - 0s - loss: 0.5209 - acc: 0.7555 - val_loss: 0.5069 - val_acc: 0.7652
#
# Epoch 00134: val_loss improved from 0.50717 to 0.50693, saving model to best_model.h5
# Epoch 135/1000
#  - 0s - loss: 0.5205 - acc: 0.7555 - val_loss: 0.5066 - val_acc: 0.7652
#
# Epoch 00135: val_loss improved from 0.50693 to 0.50659, saving model to best_model.h5
# Epoch 136/1000
#  - 0s - loss: 0.5202 - acc: 0.7555 - val_loss: 0.5064 - val_acc: 0.7652
#
# Epoch 00136: val_loss improved from 0.50659 to 0.50637, saving model to best_model.h5
# Epoch 137/1000
#  - 0s - loss: 0.5198 - acc: 0.7555 - val_loss: 0.5061 - val_acc: 0.7652
#
# Epoch 00137: val_loss improved from 0.50637 to 0.50609, saving model to best_model.h5
# Epoch 138/1000
#  - 0s - loss: 0.5196 - acc: 0.7555 - val_loss: 0.5057 - val_acc: 0.7652
#
# Epoch 00138: val_loss improved from 0.50609 to 0.50572, saving model to best_model.h5
# Epoch 139/1000
#  - 0s - loss: 0.5192 - acc: 0.7555 - val_loss: 0.5054 - val_acc: 0.7652
#
# Epoch 00139: val_loss improved from 0.50572 to 0.50535, saving model to best_model.h5
# Epoch 140/1000
#  - 0s - loss: 0.5189 - acc: 0.7555 - val_loss: 0.5050 - val_acc: 0.7652
#
# Epoch 00140: val_loss improved from 0.50535 to 0.50500, saving model to best_model.h5
# Epoch 141/1000
#  - 0s - loss: 0.5185 - acc: 0.7555 - val_loss: 0.5048 - val_acc: 0.7652
#
# Epoch 00141: val_loss improved from 0.50500 to 0.50482, saving model to best_model.h5
# Epoch 142/1000
#  - 0s - loss: 0.5185 - acc: 0.7555 - val_loss: 0.5048 - val_acc: 0.7652
#
# Epoch 00142: val_loss improved from 0.50482 to 0.50477, saving model to best_model.h5
# Epoch 143/1000
#  - 0s - loss: 0.5180 - acc: 0.7555 - val_loss: 0.5044 - val_acc: 0.7652
#
# Epoch 00143: val_loss improved from 0.50477 to 0.50441, saving model to best_model.h5
# Epoch 144/1000
#  - 0s - loss: 0.5176 - acc: 0.7555 - val_loss: 0.5038 - val_acc: 0.7652
#
# Epoch 00144: val_loss improved from 0.50441 to 0.50382, saving model to best_model.h5
# Epoch 145/1000
#  - 0s - loss: 0.5173 - acc: 0.7555 - val_loss: 0.5034 - val_acc: 0.7652
#
# Epoch 00145: val_loss improved from 0.50382 to 0.50339, saving model to best_model.h5
# Epoch 146/1000
#  - 0s - loss: 0.5170 - acc: 0.7555 - val_loss: 0.5031 - val_acc: 0.7652
#
# Epoch 00146: val_loss improved from 0.50339 to 0.50310, saving model to best_model.h5
# Epoch 147/1000
#  - 0s - loss: 0.5167 - acc: 0.7555 - val_loss: 0.5028 - val_acc: 0.7652
#
# Epoch 00147: val_loss improved from 0.50310 to 0.50277, saving model to best_model.h5
# Epoch 148/1000
#  - 0s - loss: 0.5164 - acc: 0.7555 - val_loss: 0.5025 - val_acc: 0.7652
#
# Epoch 00148: val_loss improved from 0.50277 to 0.50250, saving model to best_model.h5
# Epoch 149/1000
#  - 0s - loss: 0.5160 - acc: 0.7555 - val_loss: 0.5022 - val_acc: 0.7652
#
# Epoch 00149: val_loss improved from 0.50250 to 0.50223, saving model to best_model.h5
# Epoch 150/1000
#  - 0s - loss: 0.5158 - acc: 0.7555 - val_loss: 0.5020 - val_acc: 0.7652
#
# Epoch 00150: val_loss improved from 0.50223 to 0.50204, saving model to best_model.h5
# Epoch 151/1000
#  - 0s - loss: 0.5154 - acc: 0.7555 - val_loss: 0.5017 - val_acc: 0.7652
#
# Epoch 00151: val_loss improved from 0.50204 to 0.50172, saving model to best_model.h5
# Epoch 152/1000
#  - 0s - loss: 0.5151 - acc: 0.7555 - val_loss: 0.5013 - val_acc: 0.7652
#
# Epoch 00152: val_loss improved from 0.50172 to 0.50130, saving model to best_model.h5
# Epoch 153/1000
#  - 0s - loss: 0.5148 - acc: 0.7555 - val_loss: 0.5010 - val_acc: 0.7652
#
# Epoch 00153: val_loss improved from 0.50130 to 0.50100, saving model to best_model.h5
# Epoch 154/1000
#  - 0s - loss: 0.5145 - acc: 0.7555 - val_loss: 0.5008 - val_acc: 0.7652
#
# Epoch 00154: val_loss improved from 0.50100 to 0.50078, saving model to best_model.h5
# Epoch 155/1000
#  - 0s - loss: 0.5142 - acc: 0.7555 - val_loss: 0.5003 - val_acc: 0.7652
#
# Epoch 00155: val_loss improved from 0.50078 to 0.50033, saving model to best_model.h5
# Epoch 156/1000
#  - 0s - loss: 0.5139 - acc: 0.7555 - val_loss: 0.5001 - val_acc: 0.7652
#
# Epoch 00156: val_loss improved from 0.50033 to 0.50009, saving model to best_model.h5
# Epoch 157/1000
#  - 0s - loss: 0.5135 - acc: 0.7555 - val_loss: 0.4998 - val_acc: 0.7652
#
# Epoch 00157: val_loss improved from 0.50009 to 0.49982, saving model to best_model.h5
# Epoch 158/1000
#  - 0s - loss: 0.5133 - acc: 0.7555 - val_loss: 0.4995 - val_acc: 0.7652
#
# Epoch 00158: val_loss improved from 0.49982 to 0.49951, saving model to best_model.h5
# Epoch 159/1000
#  - 0s - loss: 0.5129 - acc: 0.7555 - val_loss: 0.4992 - val_acc: 0.7652
#
# Epoch 00159: val_loss improved from 0.49951 to 0.49920, saving model to best_model.h5
# Epoch 160/1000
#  - 0s - loss: 0.5126 - acc: 0.7555 - val_loss: 0.4990 - val_acc: 0.7652
#
# Epoch 00160: val_loss improved from 0.49920 to 0.49895, saving model to best_model.h5
# Epoch 161/1000
#  - 0s - loss: 0.5123 - acc: 0.7555 - val_loss: 0.4986 - val_acc: 0.7652
#
# Epoch 00161: val_loss improved from 0.49895 to 0.49858, saving model to best_model.h5
# Epoch 162/1000
#  - 0s - loss: 0.5121 - acc: 0.7555 - val_loss: 0.4982 - val_acc: 0.7652
#
# Epoch 00162: val_loss improved from 0.49858 to 0.49820, saving model to best_model.h5
# Epoch 163/1000
#  - 0s - loss: 0.5121 - acc: 0.7555 - val_loss: 0.4982 - val_acc: 0.7652
#
# Epoch 00163: val_loss did not improve from 0.49820
# Epoch 164/1000
#  - 0s - loss: 0.5114 - acc: 0.7555 - val_loss: 0.4979 - val_acc: 0.7652
#
# Epoch 00164: val_loss improved from 0.49820 to 0.49787, saving model to best_model.h5
# Epoch 165/1000
#  - 0s - loss: 0.5110 - acc: 0.7555 - val_loss: 0.4973 - val_acc: 0.7652
#
# Epoch 00165: val_loss improved from 0.49787 to 0.49730, saving model to best_model.h5
# Epoch 166/1000
#  - 0s - loss: 0.5108 - acc: 0.7555 - val_loss: 0.4968 - val_acc: 0.7652
#
# Epoch 00166: val_loss improved from 0.49730 to 0.49680, saving model to best_model.h5
# Epoch 167/1000
#  - 0s - loss: 0.5104 - acc: 0.7555 - val_loss: 0.4965 - val_acc: 0.7652
#
# Epoch 00167: val_loss improved from 0.49680 to 0.49653, saving model to best_model.h5
# Epoch 168/1000
#  - 0s - loss: 0.5101 - acc: 0.7555 - val_loss: 0.4963 - val_acc: 0.7652
#
# Epoch 00168: val_loss improved from 0.49653 to 0.49625, saving model to best_model.h5
# Epoch 169/1000
#  - 0s - loss: 0.5098 - acc: 0.7555 - val_loss: 0.4960 - val_acc: 0.7652
#
# Epoch 00169: val_loss improved from 0.49625 to 0.49596, saving model to best_model.h5
# Epoch 170/1000
#  - 0s - loss: 0.5096 - acc: 0.7555 - val_loss: 0.4956 - val_acc: 0.7652
#
# Epoch 00170: val_loss improved from 0.49596 to 0.49565, saving model to best_model.h5
# Epoch 171/1000
#  - 0s - loss: 0.5092 - acc: 0.7555 - val_loss: 0.4956 - val_acc: 0.7652
#
# Epoch 00171: val_loss improved from 0.49565 to 0.49564, saving model to best_model.h5
# Epoch 172/1000
#  - 0s - loss: 0.5089 - acc: 0.7555 - val_loss: 0.4954 - val_acc: 0.7652
#
# Epoch 00172: val_loss improved from 0.49564 to 0.49539, saving model to best_model.h5
# Epoch 173/1000
#  - 0s - loss: 0.5087 - acc: 0.7555 - val_loss: 0.4952 - val_acc: 0.7652
#
# Epoch 00173: val_loss improved from 0.49539 to 0.49519, saving model to best_model.h5
# Epoch 174/1000
#  - 0s - loss: 0.5082 - acc: 0.7555 - val_loss: 0.4946 - val_acc: 0.7652
#
# Epoch 00174: val_loss improved from 0.49519 to 0.49458, saving model to best_model.h5
# Epoch 175/1000
#  - 0s - loss: 0.5078 - acc: 0.7555 - val_loss: 0.4941 - val_acc: 0.7652
#
# Epoch 00175: val_loss improved from 0.49458 to 0.49405, saving model to best_model.h5
# Epoch 176/1000
#  - 0s - loss: 0.5075 - acc: 0.7555 - val_loss: 0.4937 - val_acc: 0.7652
#
# Epoch 00176: val_loss improved from 0.49405 to 0.49366, saving model to best_model.h5
# Epoch 177/1000
#  - 0s - loss: 0.5073 - acc: 0.7555 - val_loss: 0.4934 - val_acc: 0.7652
#
# Epoch 00177: val_loss improved from 0.49366 to 0.49342, saving model to best_model.h5
# Epoch 178/1000
#  - 0s - loss: 0.5069 - acc: 0.7555 - val_loss: 0.4930 - val_acc: 0.7652
#
# Epoch 00178: val_loss improved from 0.49342 to 0.49303, saving model to best_model.h5
# Epoch 179/1000
#  - 0s - loss: 0.5066 - acc: 0.7555 - val_loss: 0.4928 - val_acc: 0.7652
#
# Epoch 00179: val_loss improved from 0.49303 to 0.49275, saving model to best_model.h5
# Epoch 180/1000
#  - 0s - loss: 0.5063 - acc: 0.7555 - val_loss: 0.4926 - val_acc: 0.7652
#
# Epoch 00180: val_loss improved from 0.49275 to 0.49257, saving model to best_model.h5
# Epoch 181/1000
#  - 0s - loss: 0.5059 - acc: 0.7555 - val_loss: 0.4923 - val_acc: 0.7652
#
# Epoch 00181: val_loss improved from 0.49257 to 0.49226, saving model to best_model.h5
# Epoch 182/1000
#  - 0s - loss: 0.5057 - acc: 0.7555 - val_loss: 0.4917 - val_acc: 0.7652
#
# Epoch 00182: val_loss improved from 0.49226 to 0.49173, saving model to best_model.h5
# Epoch 183/1000
#  - 0s - loss: 0.5053 - acc: 0.7555 - val_loss: 0.4915 - val_acc: 0.7652
#
# Epoch 00183: val_loss improved from 0.49173 to 0.49150, saving model to best_model.h5
# Epoch 184/1000
#  - 0s - loss: 0.5051 - acc: 0.7555 - val_loss: 0.4914 - val_acc: 0.7652
#
# Epoch 00184: val_loss improved from 0.49150 to 0.49136, saving model to best_model.h5
# Epoch 185/1000
#  - 0s - loss: 0.5047 - acc: 0.7555 - val_loss: 0.4909 - val_acc: 0.7652
#
# Epoch 00185: val_loss improved from 0.49136 to 0.49091, saving model to best_model.h5
# Epoch 186/1000
#  - 0s - loss: 0.5043 - acc: 0.7555 - val_loss: 0.4906 - val_acc: 0.7652
#
# Epoch 00186: val_loss improved from 0.49091 to 0.49063, saving model to best_model.h5
# Epoch 187/1000
#  - 0s - loss: 0.5040 - acc: 0.7555 - val_loss: 0.4903 - val_acc: 0.7652
#
# Epoch 00187: val_loss improved from 0.49063 to 0.49029, saving model to best_model.h5
# Epoch 188/1000
#  - 0s - loss: 0.5036 - acc: 0.7555 - val_loss: 0.4899 - val_acc: 0.7652
#
# Epoch 00188: val_loss improved from 0.49029 to 0.48988, saving model to best_model.h5
# Epoch 189/1000
#  - 0s - loss: 0.5033 - acc: 0.7555 - val_loss: 0.4894 - val_acc: 0.7652
#
# Epoch 00189: val_loss improved from 0.48988 to 0.48941, saving model to best_model.h5
# Epoch 190/1000
#  - 0s - loss: 0.5030 - acc: 0.7555 - val_loss: 0.4892 - val_acc: 0.7652
#
# Epoch 00190: val_loss improved from 0.48941 to 0.48915, saving model to best_model.h5
# Epoch 191/1000
#  - 0s - loss: 0.5027 - acc: 0.7555 - val_loss: 0.4888 - val_acc: 0.7652
#
# Epoch 00191: val_loss improved from 0.48915 to 0.48883, saving model to best_model.h5
# Epoch 192/1000
#  - 0s - loss: 0.5023 - acc: 0.7555 - val_loss: 0.4885 - val_acc: 0.7652
#
# Epoch 00192: val_loss improved from 0.48883 to 0.48846, saving model to best_model.h5
# Epoch 193/1000
#  - 0s - loss: 0.5020 - acc: 0.7555 - val_loss: 0.4882 - val_acc: 0.7652
#
# Epoch 00193: val_loss improved from 0.48846 to 0.48820, saving model to best_model.h5
# Epoch 194/1000
#  - 0s - loss: 0.5016 - acc: 0.7555 - val_loss: 0.4878 - val_acc: 0.7652
#
# Epoch 00194: val_loss improved from 0.48820 to 0.48781, saving model to best_model.h5
# Epoch 195/1000
#  - 0s - loss: 0.5014 - acc: 0.7555 - val_loss: 0.4873 - val_acc: 0.7652
#
# Epoch 00195: val_loss improved from 0.48781 to 0.48732, saving model to best_model.h5
# Epoch 196/1000
#  - 0s - loss: 0.5010 - acc: 0.7555 - val_loss: 0.4870 - val_acc: 0.7652
#
# Epoch 00196: val_loss improved from 0.48732 to 0.48701, saving model to best_model.h5
# Epoch 197/1000
#  - 0s - loss: 0.5010 - acc: 0.7555 - val_loss: 0.4871 - val_acc: 0.7652
#
# Epoch 00197: val_loss did not improve from 0.48701
# Epoch 198/1000
#  - 0s - loss: 0.5003 - acc: 0.7555 - val_loss: 0.4866 - val_acc: 0.7652
#
# Epoch 00198: val_loss improved from 0.48701 to 0.48663, saving model to best_model.h5
# Epoch 199/1000
#  - 0s - loss: 0.5000 - acc: 0.7555 - val_loss: 0.4861 - val_acc: 0.7652
#
# Epoch 00199: val_loss improved from 0.48663 to 0.48611, saving model to best_model.h5
# Epoch 200/1000
#  - 0s - loss: 0.4997 - acc: 0.7555 - val_loss: 0.4858 - val_acc: 0.7652
#
# Epoch 00200: val_loss improved from 0.48611 to 0.48584, saving model to best_model.h5
# Epoch 201/1000
#  - 0s - loss: 0.4995 - acc: 0.7555 - val_loss: 0.4852 - val_acc: 0.7652
#
# Epoch 00201: val_loss improved from 0.48584 to 0.48521, saving model to best_model.h5
# Epoch 202/1000
#  - 0s - loss: 0.4990 - acc: 0.7555 - val_loss: 0.4850 - val_acc: 0.7652
#
# Epoch 00202: val_loss improved from 0.48521 to 0.48498, saving model to best_model.h5
# Epoch 203/1000
#  - 0s - loss: 0.4986 - acc: 0.7555 - val_loss: 0.4847 - val_acc: 0.7652
#
# Epoch 00203: val_loss improved from 0.48498 to 0.48468, saving model to best_model.h5
# Epoch 204/1000
#  - 0s - loss: 0.4983 - acc: 0.7555 - val_loss: 0.4843 - val_acc: 0.7652
#
# Epoch 00204: val_loss improved from 0.48468 to 0.48430, saving model to best_model.h5
# Epoch 205/1000
#  - 0s - loss: 0.4981 - acc: 0.7555 - val_loss: 0.4842 - val_acc: 0.7652
#
# Epoch 00205: val_loss improved from 0.48430 to 0.48421, saving model to best_model.h5
# Epoch 206/1000
#  - 0s - loss: 0.4976 - acc: 0.7557 - val_loss: 0.4836 - val_acc: 0.7652
#
# Epoch 00206: val_loss improved from 0.48421 to 0.48360, saving model to best_model.h5
# Epoch 207/1000
#  - 0s - loss: 0.4972 - acc: 0.7557 - val_loss: 0.4833 - val_acc: 0.7652
#
# Epoch 00207: val_loss improved from 0.48360 to 0.48330, saving model to best_model.h5
# Epoch 208/1000
#  - 0s - loss: 0.4972 - acc: 0.7555 - val_loss: 0.4827 - val_acc: 0.7652
#
# Epoch 00208: val_loss improved from 0.48330 to 0.48267, saving model to best_model.h5
# Epoch 209/1000
#  - 0s - loss: 0.4967 - acc: 0.7557 - val_loss: 0.4825 - val_acc: 0.7652
#
# Epoch 00209: val_loss improved from 0.48267 to 0.48252, saving model to best_model.h5
# Epoch 210/1000
#  - 0s - loss: 0.4963 - acc: 0.7557 - val_loss: 0.4823 - val_acc: 0.7652
#
# Epoch 00210: val_loss improved from 0.48252 to 0.48233, saving model to best_model.h5
# Epoch 211/1000
#  - 0s - loss: 0.4959 - acc: 0.7559 - val_loss: 0.4818 - val_acc: 0.7652
#
# Epoch 00211: val_loss improved from 0.48233 to 0.48177, saving model to best_model.h5
# Epoch 212/1000
#  - 0s - loss: 0.4955 - acc: 0.7557 - val_loss: 0.4813 - val_acc: 0.7652
#
# Epoch 00212: val_loss improved from 0.48177 to 0.48130, saving model to best_model.h5
# Epoch 213/1000
#  - 0s - loss: 0.4952 - acc: 0.7559 - val_loss: 0.4810 - val_acc: 0.7652
#
# Epoch 00213: val_loss improved from 0.48130 to 0.48104, saving model to best_model.h5
# Epoch 214/1000
#  - 0s - loss: 0.4950 - acc: 0.7559 - val_loss: 0.4809 - val_acc: 0.7652
#
# Epoch 00214: val_loss improved from 0.48104 to 0.48095, saving model to best_model.h5
# Epoch 215/1000
#  - 0s - loss: 0.4946 - acc: 0.7559 - val_loss: 0.4803 - val_acc: 0.7652
#
# Epoch 00215: val_loss improved from 0.48095 to 0.48030, saving model to best_model.h5
# Epoch 216/1000
#  - 0s - loss: 0.4941 - acc: 0.7559 - val_loss: 0.4799 - val_acc: 0.7652
#
# Epoch 00216: val_loss improved from 0.48030 to 0.47993, saving model to best_model.h5
# Epoch 217/1000
#  - 0s - loss: 0.4939 - acc: 0.7564 - val_loss: 0.4798 - val_acc: 0.7652
#
# Epoch 00217: val_loss improved from 0.47993 to 0.47978, saving model to best_model.h5
# Epoch 218/1000
#  - 0s - loss: 0.4935 - acc: 0.7566 - val_loss: 0.4795 - val_acc: 0.7660
#
# Epoch 00218: val_loss improved from 0.47978 to 0.47953, saving model to best_model.h5
# Epoch 219/1000
#  - 0s - loss: 0.4931 - acc: 0.7566 - val_loss: 0.4790 - val_acc: 0.7660
#
# Epoch 00219: val_loss improved from 0.47953 to 0.47903, saving model to best_model.h5
# Epoch 220/1000
#  - 0s - loss: 0.4929 - acc: 0.7564 - val_loss: 0.4783 - val_acc: 0.7660
#
# Epoch 00220: val_loss improved from 0.47903 to 0.47831, saving model to best_model.h5
# Epoch 221/1000
#  - 0s - loss: 0.4924 - acc: 0.7562 - val_loss: 0.4780 - val_acc: 0.7660
#
# Epoch 00221: val_loss improved from 0.47831 to 0.47797, saving model to best_model.h5
# Epoch 222/1000
#  - 0s - loss: 0.4921 - acc: 0.7564 - val_loss: 0.4778 - val_acc: 0.7660
#
# Epoch 00222: val_loss improved from 0.47797 to 0.47779, saving model to best_model.h5
# Epoch 223/1000
#  - 0s - loss: 0.4917 - acc: 0.7566 - val_loss: 0.4775 - val_acc: 0.7660
#
# Epoch 00223: val_loss improved from 0.47779 to 0.47750, saving model to best_model.h5
# Epoch 224/1000
#  - 0s - loss: 0.4914 - acc: 0.7568 - val_loss: 0.4772 - val_acc: 0.7660
#
# Epoch 00224: val_loss improved from 0.47750 to 0.47721, saving model to best_model.h5
# Epoch 225/1000
#  - 0s - loss: 0.4910 - acc: 0.7572 - val_loss: 0.4768 - val_acc: 0.7660
#
# Epoch 00225: val_loss improved from 0.47721 to 0.47679, saving model to best_model.h5
# Epoch 226/1000
#  - 0s - loss: 0.4906 - acc: 0.7568 - val_loss: 0.4762 - val_acc: 0.7660
#
# Epoch 00226: val_loss improved from 0.47679 to 0.47622, saving model to best_model.h5
# Epoch 227/1000
#  - 0s - loss: 0.4903 - acc: 0.7572 - val_loss: 0.4759 - val_acc: 0.7660
#
# Epoch 00227: val_loss improved from 0.47622 to 0.47590, saving model to best_model.h5
# Epoch 228/1000
#  - 0s - loss: 0.4899 - acc: 0.7573 - val_loss: 0.4756 - val_acc: 0.7660
#
# Epoch 00228: val_loss improved from 0.47590 to 0.47557, saving model to best_model.h5
# Epoch 229/1000
#  - 0s - loss: 0.4896 - acc: 0.7583 - val_loss: 0.4752 - val_acc: 0.7660
#
# Epoch 00229: val_loss improved from 0.47557 to 0.47523, saving model to best_model.h5
# Epoch 230/1000
#  - 0s - loss: 0.4892 - acc: 0.7581 - val_loss: 0.4748 - val_acc: 0.7660
#
# Epoch 00230: val_loss improved from 0.47523 to 0.47483, saving model to best_model.h5
# Epoch 231/1000
#  - 0s - loss: 0.4888 - acc: 0.7584 - val_loss: 0.4745 - val_acc: 0.7652
#
# Epoch 00231: val_loss improved from 0.47483 to 0.47452, saving model to best_model.h5
# Epoch 232/1000
#  - 0s - loss: 0.4885 - acc: 0.7583 - val_loss: 0.4742 - val_acc: 0.7652
#
# Epoch 00232: val_loss improved from 0.47452 to 0.47425, saving model to best_model.h5
# Epoch 233/1000
#  - 0s - loss: 0.4882 - acc: 0.7586 - val_loss: 0.4740 - val_acc: 0.7667
#
# Epoch 00233: val_loss improved from 0.47425 to 0.47396, saving model to best_model.h5
# Epoch 234/1000
#  - 0s - loss: 0.4879 - acc: 0.7588 - val_loss: 0.4735 - val_acc: 0.7667
#
# Epoch 00234: val_loss improved from 0.47396 to 0.47355, saving model to best_model.h5
# Epoch 235/1000
#  - 0s - loss: 0.4876 - acc: 0.7590 - val_loss: 0.4729 - val_acc: 0.7652
#
# Epoch 00235: val_loss improved from 0.47355 to 0.47290, saving model to best_model.h5
# Epoch 236/1000
#  - 0s - loss: 0.4871 - acc: 0.7590 - val_loss: 0.4727 - val_acc: 0.7667
#
# Epoch 00236: val_loss improved from 0.47290 to 0.47271, saving model to best_model.h5
# Epoch 237/1000
#  - 0s - loss: 0.4868 - acc: 0.7592 - val_loss: 0.4722 - val_acc: 0.7667
#
# Epoch 00237: val_loss improved from 0.47271 to 0.47217, saving model to best_model.h5
# Epoch 238/1000
#  - 0s - loss: 0.4865 - acc: 0.7588 - val_loss: 0.4718 - val_acc: 0.7667
#
# Epoch 00238: val_loss improved from 0.47217 to 0.47176, saving model to best_model.h5
# Epoch 239/1000
#  - 0s - loss: 0.4861 - acc: 0.7599 - val_loss: 0.4716 - val_acc: 0.7682
#
# Epoch 00239: val_loss improved from 0.47176 to 0.47162, saving model to best_model.h5
# Epoch 240/1000
#  - 0s - loss: 0.4857 - acc: 0.7605 - val_loss: 0.4713 - val_acc: 0.7674
#
# Epoch 00240: val_loss improved from 0.47162 to 0.47132, saving model to best_model.h5
# Epoch 241/1000
#  - 0s - loss: 0.4855 - acc: 0.7601 - val_loss: 0.4707 - val_acc: 0.7674
#
# Epoch 00241: val_loss improved from 0.47132 to 0.47070, saving model to best_model.h5
# Epoch 242/1000
#  - 0s - loss: 0.4850 - acc: 0.7605 - val_loss: 0.4705 - val_acc: 0.7682
#
# Epoch 00242: val_loss improved from 0.47070 to 0.47049, saving model to best_model.h5
# Epoch 243/1000
#  - 0s - loss: 0.4846 - acc: 0.7610 - val_loss: 0.4701 - val_acc: 0.7682
#
# Epoch 00243: val_loss improved from 0.47049 to 0.47012, saving model to best_model.h5
# Epoch 244/1000
#  - 0s - loss: 0.4843 - acc: 0.7617 - val_loss: 0.4698 - val_acc: 0.7696
#
# Epoch 00244: val_loss improved from 0.47012 to 0.46979, saving model to best_model.h5
# Epoch 245/1000
#  - 0s - loss: 0.4839 - acc: 0.7621 - val_loss: 0.4695 - val_acc: 0.7696
#
# Epoch 00245: val_loss improved from 0.46979 to 0.46946, saving model to best_model.h5
# Epoch 246/1000
#  - 0s - loss: 0.4837 - acc: 0.7619 - val_loss: 0.4689 - val_acc: 0.7696
#
# Epoch 00246: val_loss improved from 0.46946 to 0.46889, saving model to best_model.h5
# Epoch 247/1000
#  - 0s - loss: 0.4838 - acc: 0.7603 - val_loss: 0.4683 - val_acc: 0.7674
#
# Epoch 00247: val_loss improved from 0.46889 to 0.46829, saving model to best_model.h5
# Epoch 248/1000
#  - 0s - loss: 0.4828 - acc: 0.7616 - val_loss: 0.4682 - val_acc: 0.7704
#
# Epoch 00248: val_loss improved from 0.46829 to 0.46824, saving model to best_model.h5
# Epoch 249/1000
#  - 0s - loss: 0.4825 - acc: 0.7625 - val_loss: 0.4680 - val_acc: 0.7726
#
# Epoch 00249: val_loss improved from 0.46824 to 0.46800, saving model to best_model.h5
# Epoch 250/1000
#  - 0s - loss: 0.4822 - acc: 0.7628 - val_loss: 0.4677 - val_acc: 0.7726
#
# Epoch 00250: val_loss improved from 0.46800 to 0.46769, saving model to best_model.h5
# Epoch 251/1000
#  - 0s - loss: 0.4819 - acc: 0.7630 - val_loss: 0.4670 - val_acc: 0.7704
#
# Epoch 00251: val_loss improved from 0.46769 to 0.46697, saving model to best_model.h5
# Epoch 252/1000
#  - 0s - loss: 0.4814 - acc: 0.7625 - val_loss: 0.4667 - val_acc: 0.7718
#
# Epoch 00252: val_loss improved from 0.46697 to 0.46668, saving model to best_model.h5
# Epoch 253/1000
#  - 0s - loss: 0.4812 - acc: 0.7630 - val_loss: 0.4664 - val_acc: 0.7726
#
# Epoch 00253: val_loss improved from 0.46668 to 0.46639, saving model to best_model.h5
# Epoch 254/1000
#  - 0s - loss: 0.4807 - acc: 0.7628 - val_loss: 0.4658 - val_acc: 0.7718
#
# Epoch 00254: val_loss improved from 0.46639 to 0.46579, saving model to best_model.h5
# Epoch 255/1000
#  - 0s - loss: 0.4805 - acc: 0.7628 - val_loss: 0.4655 - val_acc: 0.7726
#
# Epoch 00255: val_loss improved from 0.46579 to 0.46552, saving model to best_model.h5
# Epoch 256/1000
#  - 0s - loss: 0.4801 - acc: 0.7625 - val_loss: 0.4651 - val_acc: 0.7726
#
# Epoch 00256: val_loss improved from 0.46552 to 0.46508, saving model to best_model.h5
# Epoch 257/1000
#  - 0s - loss: 0.4797 - acc: 0.7634 - val_loss: 0.4649 - val_acc: 0.7726
#
# Epoch 00257: val_loss improved from 0.46508 to 0.46489, saving model to best_model.h5
# Epoch 258/1000
#  - 0s - loss: 0.4793 - acc: 0.7632 - val_loss: 0.4643 - val_acc: 0.7726
#
# Epoch 00258: val_loss improved from 0.46489 to 0.46433, saving model to best_model.h5
# Epoch 259/1000
#  - 0s - loss: 0.4789 - acc: 0.7636 - val_loss: 0.4640 - val_acc: 0.7726
#
# Epoch 00259: val_loss improved from 0.46433 to 0.46397, saving model to best_model.h5
# Epoch 260/1000
#  - 0s - loss: 0.4786 - acc: 0.7630 - val_loss: 0.4637 - val_acc: 0.7733
#
# Epoch 00260: val_loss improved from 0.46397 to 0.46370, saving model to best_model.h5
# Epoch 261/1000
#  - 0s - loss: 0.4786 - acc: 0.7650 - val_loss: 0.4636 - val_acc: 0.7733
#
# Epoch 00261: val_loss improved from 0.46370 to 0.46364, saving model to best_model.h5
# Epoch 262/1000
#  - 0s - loss: 0.4779 - acc: 0.7645 - val_loss: 0.4630 - val_acc: 0.7726
#
# Epoch 00262: val_loss improved from 0.46364 to 0.46299, saving model to best_model.h5
# Epoch 263/1000
#  - 0s - loss: 0.4775 - acc: 0.7641 - val_loss: 0.4624 - val_acc: 0.7726
#
# Epoch 00263: val_loss improved from 0.46299 to 0.46238, saving model to best_model.h5
# Epoch 264/1000
#  - 0s - loss: 0.4772 - acc: 0.7638 - val_loss: 0.4620 - val_acc: 0.7733
#
# Epoch 00264: val_loss improved from 0.46238 to 0.46200, saving model to best_model.h5
# Epoch 265/1000
#  - 0s - loss: 0.4769 - acc: 0.7641 - val_loss: 0.4616 - val_acc: 0.7733
#
# Epoch 00265: val_loss improved from 0.46200 to 0.46157, saving model to best_model.h5
# Epoch 266/1000
#  - 0s - loss: 0.4766 - acc: 0.7639 - val_loss: 0.4613 - val_acc: 0.7726
#
# Epoch 00266: val_loss improved from 0.46157 to 0.46126, saving model to best_model.h5
# Epoch 267/1000
#  - 0s - loss: 0.4763 - acc: 0.7652 - val_loss: 0.4610 - val_acc: 0.7748
#
# Epoch 00267: val_loss improved from 0.46126 to 0.46104, saving model to best_model.h5
# Epoch 268/1000
#  - 0s - loss: 0.4758 - acc: 0.7654 - val_loss: 0.4608 - val_acc: 0.7748
#
# Epoch 00268: val_loss improved from 0.46104 to 0.46080, saving model to best_model.h5
# Epoch 269/1000
#  - 0s - loss: 0.4755 - acc: 0.7650 - val_loss: 0.4602 - val_acc: 0.7740
#
# Epoch 00269: val_loss improved from 0.46080 to 0.46019, saving model to best_model.h5
# Epoch 270/1000
#  - 0s - loss: 0.4751 - acc: 0.7652 - val_loss: 0.4600 - val_acc: 0.7748
#
# Epoch 00270: val_loss improved from 0.46019 to 0.45999, saving model to best_model.h5
# Epoch 271/1000
#  - 0s - loss: 0.4748 - acc: 0.7667 - val_loss: 0.4597 - val_acc: 0.7762
#
# Epoch 00271: val_loss improved from 0.45999 to 0.45973, saving model to best_model.h5
# Epoch 272/1000
#  - 0s - loss: 0.4745 - acc: 0.7667 - val_loss: 0.4593 - val_acc: 0.7762
#
# Epoch 00272: val_loss improved from 0.45973 to 0.45926, saving model to best_model.h5
# Epoch 273/1000
#  - 0s - loss: 0.4740 - acc: 0.7656 - val_loss: 0.4585 - val_acc: 0.7740
#
# Epoch 00273: val_loss improved from 0.45926 to 0.45845, saving model to best_model.h5
# Epoch 274/1000
#  - 0s - loss: 0.4738 - acc: 0.7643 - val_loss: 0.4581 - val_acc: 0.7748
#
# Epoch 00274: val_loss improved from 0.45845 to 0.45807, saving model to best_model.h5
# Epoch 275/1000
#  - 0s - loss: 0.4736 - acc: 0.7649 - val_loss: 0.4579 - val_acc: 0.7762
#
# Epoch 00275: val_loss improved from 0.45807 to 0.45791, saving model to best_model.h5
# Epoch 276/1000
#  - 0s - loss: 0.4729 - acc: 0.7667 - val_loss: 0.4576 - val_acc: 0.7762
#
# Epoch 00276: val_loss improved from 0.45791 to 0.45762, saving model to best_model.h5
# Epoch 277/1000
#  - 0s - loss: 0.4728 - acc: 0.7672 - val_loss: 0.4577 - val_acc: 0.7792
#
# ...
# Epoch 890/1000
#  - 0s - loss: 0.4059 - acc: 0.8036 - val_loss: 0.3786 - val_acc: 0.8107
#
# Epoch 00890: val_loss did not improve from 0.37789
# Epoch 891/1000
#  - 0s - loss: 0.4056 - acc: 0.8025 - val_loss: 0.3783 - val_acc: 0.8100
#
# Epoch 00891: val_loss did not improve from 0.37789
# Epoch 892/1000
#  - 0s - loss: 0.4058 - acc: 0.8021 - val_loss: 0.3789 - val_acc: 0.8122
#
# Epoch 00892: val_loss did not improve from 0.37789
# Epoch 893/1000
#  - 0s - loss: 0.4056 - acc: 0.8026 - val_loss: 0.3782 - val_acc: 0.8107
#
# Epoch 00893: val_loss did not improve from 0.37789
# Epoch 894/1000
#  - 0s - loss: 0.4055 - acc: 0.8034 - val_loss: 0.3784 - val_acc: 0.8107
#
# Epoch 00894: val_loss did not improve from 0.37789
# Epoch 895/1000
#  - 0s - loss: 0.4059 - acc: 0.8039 - val_loss: 0.3783 - val_acc: 0.8107
#
# Epoch 00895: val_loss did not improve from 0.37789
# Epoch 896/1000
#  - 0s - loss: 0.4054 - acc: 0.8030 - val_loss: 0.3782 - val_acc: 0.8107
#
# Epoch 00896: val_loss did not improve from 0.37789
# Epoch 897/1000
#  - 0s - loss: 0.4056 - acc: 0.8025 - val_loss: 0.3787 - val_acc: 0.8107
#
# Epoch 00897: val_loss did not improve from 0.37789
# Epoch 898/1000
#  - 0s - loss: 0.4060 - acc: 0.8034 - val_loss: 0.3779 - val_acc: 0.8085
#
# Epoch 00898: val_loss improved from 0.37789 to 0.37786, saving model to best_model.h5
# Epoch 899/1000
#  - 0s - loss: 0.4054 - acc: 0.8041 - val_loss: 0.3786 - val_acc: 0.8107
#
# Epoch 00899: val_loss did not improve from 0.37786
# Epoch 900/1000
#  - 0s - loss: 0.4062 - acc: 0.8034 - val_loss: 0.3790 - val_acc: 0.8151
#
# Epoch 00900: val_loss did not improve from 0.37786
# Epoch 901/1000
#  - 0s - loss: 0.4055 - acc: 0.8034 - val_loss: 0.3780 - val_acc: 0.8092
#
# Epoch 00901: val_loss did not improve from 0.37786
# Epoch 902/1000
#  - 0s - loss: 0.4056 - acc: 0.8039 - val_loss: 0.3779 - val_acc: 0.8078
#
# Epoch 00902: val_loss did not improve from 0.37786
# Epoch 903/1000
#  - 0s - loss: 0.4056 - acc: 0.8026 - val_loss: 0.3784 - val_acc: 0.8114
#
# Epoch 00903: val_loss did not improve from 0.37786
# Epoch 904/1000
#  - 0s - loss: 0.4054 - acc: 0.8026 - val_loss: 0.3785 - val_acc: 0.8122
#
# Epoch 00904: val_loss did not improve from 0.37786
# Epoch 905/1000
#  - 0s - loss: 0.4053 - acc: 0.8030 - val_loss: 0.3782 - val_acc: 0.8114
#
# Epoch 00905: val_loss did not improve from 0.37786
# Epoch 906/1000
#  - 0s - loss: 0.4053 - acc: 0.8034 - val_loss: 0.3779 - val_acc: 0.8085
#
# Epoch 00906: val_loss did not improve from 0.37786
# Epoch 907/1000
#  - 0s - loss: 0.4053 - acc: 0.8039 - val_loss: 0.3782 - val_acc: 0.8107
#
# Epoch 00907: val_loss did not improve from 0.37786
# Epoch 908/1000
#  - 0s - loss: 0.4056 - acc: 0.8026 - val_loss: 0.3783 - val_acc: 0.8107
#
# Epoch 00908: val_loss did not improve from 0.37786
# Epoch 909/1000
#  - 0s - loss: 0.4054 - acc: 0.8034 - val_loss: 0.3780 - val_acc: 0.8107
#
# Epoch 00909: val_loss did not improve from 0.37786
# Epoch 910/1000
#  - 0s - loss: 0.4052 - acc: 0.8023 - val_loss: 0.3784 - val_acc: 0.8114
#
# Epoch 00910: val_loss did not improve from 0.37786
# Epoch 911/1000
#  - 0s - loss: 0.4057 - acc: 0.8026 - val_loss: 0.3779 - val_acc: 0.8114
#
# Epoch 00911: val_loss improved from 0.37786 to 0.37785, saving model to best_model.h5
# Epoch 912/1000
#  - 0s - loss: 0.4056 - acc: 0.8037 - val_loss: 0.3778 - val_acc: 0.8100
#
# Epoch 00912: val_loss improved from 0.37785 to 0.37783, saving model to best_model.h5
# Epoch 913/1000
#  - 0s - loss: 0.4051 - acc: 0.8039 - val_loss: 0.3784 - val_acc: 0.8129
#
# Epoch 00913: val_loss did not improve from 0.37783
# Epoch 914/1000
#  - 0s - loss: 0.4053 - acc: 0.8021 - val_loss: 0.3793 - val_acc: 0.8144
#
# Epoch 00914: val_loss did not improve from 0.37783
# Epoch 915/1000
#  - 0s - loss: 0.4053 - acc: 0.8025 - val_loss: 0.3786 - val_acc: 0.8151
#
# Epoch 00915: val_loss did not improve from 0.37783
# Epoch 916/1000
#  - 0s - loss: 0.4052 - acc: 0.8028 - val_loss: 0.3777 - val_acc: 0.8078
#
# Epoch 00916: val_loss improved from 0.37783 to 0.37767, saving model to best_model.h5
# Epoch 917/1000
#  - 0s - loss: 0.4055 - acc: 0.8039 - val_loss: 0.3781 - val_acc: 0.8107
#
# Epoch 00917: val_loss did not improve from 0.37767
# Epoch 918/1000
#  - 0s - loss: 0.4061 - acc: 0.8023 - val_loss: 0.3786 - val_acc: 0.8151
#
# Epoch 00918: val_loss did not improve from 0.37767
# Epoch 919/1000
#  - 0s - loss: 0.4058 - acc: 0.8034 - val_loss: 0.3775 - val_acc: 0.8092
#
# Epoch 00919: val_loss improved from 0.37767 to 0.37746, saving model to best_model.h5
# Epoch 920/1000
#  - 0s - loss: 0.4055 - acc: 0.8048 - val_loss: 0.3777 - val_acc: 0.8107
#
# Epoch 00920: val_loss did not improve from 0.37746
# Epoch 921/1000
#  - 0s - loss: 0.4050 - acc: 0.8030 - val_loss: 0.3783 - val_acc: 0.8136
#
# Epoch 00921: val_loss did not improve from 0.37746
# Epoch 922/1000
#  - 0s - loss: 0.4052 - acc: 0.8023 - val_loss: 0.3786 - val_acc: 0.8151
#
# Epoch 00922: val_loss did not improve from 0.37746
# Epoch 923/1000
#  - 0s - loss: 0.4055 - acc: 0.8025 - val_loss: 0.3779 - val_acc: 0.8107
#
# Epoch 00923: val_loss did not improve from 0.37746
# Epoch 924/1000
#  - 0s - loss: 0.4051 - acc: 0.8041 - val_loss: 0.3776 - val_acc: 0.8085
#
# Epoch 00924: val_loss did not improve from 0.37746
# Epoch 925/1000
#  - 0s - loss: 0.4053 - acc: 0.8041 - val_loss: 0.3779 - val_acc: 0.8107
#
# Epoch 00925: val_loss did not improve from 0.37746
# Epoch 926/1000
#  - 0s - loss: 0.4052 - acc: 0.8025 - val_loss: 0.3778 - val_acc: 0.8107
#
# Epoch 00926: val_loss did not improve from 0.37746
# Epoch 927/1000
#  - 0s - loss: 0.4054 - acc: 0.8041 - val_loss: 0.3776 - val_acc: 0.8085
#
# Epoch 00927: val_loss did not improve from 0.37746
# Epoch 928/1000
#  - 0s - loss: 0.4049 - acc: 0.8043 - val_loss: 0.3779 - val_acc: 0.8100
#
# Epoch 00928: val_loss did not improve from 0.37746
# Epoch 929/1000
#  - 0s - loss: 0.4058 - acc: 0.8036 - val_loss: 0.3789 - val_acc: 0.8144
#
# Epoch 00929: val_loss did not improve from 0.37746
# Epoch 930/1000
#  - 0s - loss: 0.4051 - acc: 0.8026 - val_loss: 0.3780 - val_acc: 0.8129
#
# Epoch 00930: val_loss did not improve from 0.37746
# Epoch 931/1000
#  - 0s - loss: 0.4055 - acc: 0.8039 - val_loss: 0.3773 - val_acc: 0.8070
#
# Epoch 00931: val_loss improved from 0.37746 to 0.37731, saving model to best_model.h5
# Epoch 932/1000
#  - 0s - loss: 0.4057 - acc: 0.8043 - val_loss: 0.3778 - val_acc: 0.8100
#
# Epoch 00932: val_loss did not improve from 0.37731
# Epoch 933/1000
#  - 0s - loss: 0.4050 - acc: 0.8028 - val_loss: 0.3781 - val_acc: 0.8166
#
# Epoch 00933: val_loss did not improve from 0.37731
# Epoch 934/1000
#  - 0s - loss: 0.4051 - acc: 0.8030 - val_loss: 0.3783 - val_acc: 0.8151
#
# Epoch 00934: val_loss did not improve from 0.37731
# Epoch 935/1000
#  - 0s - loss: 0.4058 - acc: 0.8043 - val_loss: 0.3775 - val_acc: 0.8085
#
# Epoch 00935: val_loss did not improve from 0.37731
# Epoch 936/1000
#  - 0s - loss: 0.4051 - acc: 0.8052 - val_loss: 0.3774 - val_acc: 0.8070
#
# Epoch 00936: val_loss did not improve from 0.37731
# Epoch 937/1000
#  - 0s - loss: 0.4048 - acc: 0.8039 - val_loss: 0.3782 - val_acc: 0.8158
#
# Epoch 00937: val_loss did not improve from 0.37731
# Epoch 938/1000
#  - 0s - loss: 0.4057 - acc: 0.8036 - val_loss: 0.3789 - val_acc: 0.8151
#
# Epoch 00938: val_loss did not improve from 0.37731
# Epoch 939/1000
#  - 0s - loss: 0.4046 - acc: 0.8032 - val_loss: 0.3774 - val_acc: 0.8078
#
# Epoch 00939: val_loss did not improve from 0.37731
# Epoch 940/1000
#  - 0s - loss: 0.4049 - acc: 0.8048 - val_loss: 0.3773 - val_acc: 0.8085
#
# Epoch 00940: val_loss improved from 0.37731 to 0.37726, saving model to best_model.h5
# Epoch 941/1000
#  - 0s - loss: 0.4048 - acc: 0.8043 - val_loss: 0.3776 - val_acc: 0.8107
#
# Epoch 00941: val_loss did not improve from 0.37726
# Epoch 942/1000
#  - 0s - loss: 0.4048 - acc: 0.8026 - val_loss: 0.3785 - val_acc: 0.8151
#
# Epoch 00942: val_loss did not improve from 0.37726
# Epoch 943/1000
#  - 0s - loss: 0.4050 - acc: 0.8032 - val_loss: 0.3785 - val_acc: 0.8144
#
# Epoch 00943: val_loss did not improve from 0.37726
# Epoch 944/1000
#  - 0s - loss: 0.4050 - acc: 0.8041 - val_loss: 0.3772 - val_acc: 0.8085
#
# Epoch 00944: val_loss improved from 0.37726 to 0.37719, saving model to best_model.h5
# Epoch 945/1000
#  - 0s - loss: 0.4049 - acc: 0.8058 - val_loss: 0.3773 - val_acc: 0.8078
#
# Epoch 00945: val_loss did not improve from 0.37719
# Epoch 946/1000
#  - 0s - loss: 0.4048 - acc: 0.8052 - val_loss: 0.3778 - val_acc: 0.8136
#
# Epoch 00946: val_loss did not improve from 0.37719
# Epoch 947/1000
#  - 0s - loss: 0.4065 - acc: 0.8032 - val_loss: 0.3803 - val_acc: 0.8136
#
# Epoch 00947: val_loss did not improve from 0.37719
# Epoch 948/1000
#  - 0s - loss: 0.4053 - acc: 0.8034 - val_loss: 0.3773 - val_acc: 0.8078
#
# Epoch 00948: val_loss did not improve from 0.37719
# Epoch 949/1000
#  - 0s - loss: 0.4057 - acc: 0.8047 - val_loss: 0.3770 - val_acc: 0.8070
#
# Epoch 00949: val_loss improved from 0.37719 to 0.37701, saving model to best_model.h5
# Epoch 950/1000
#  - 0s - loss: 0.4050 - acc: 0.8045 - val_loss: 0.3778 - val_acc: 0.8151
#
# Epoch 00950: val_loss did not improve from 0.37701
# Epoch 951/1000
#  - 0s - loss: 0.4054 - acc: 0.8056 - val_loss: 0.3791 - val_acc: 0.8158
#
# Epoch 00951: val_loss did not improve from 0.37701
# Epoch 952/1000
#  - 0s - loss: 0.4053 - acc: 0.8032 - val_loss: 0.3774 - val_acc: 0.8107
#
# Epoch 00952: val_loss did not improve from 0.37701
# Epoch 953/1000
#  - 0s - loss: 0.4047 - acc: 0.8047 - val_loss: 0.3774 - val_acc: 0.8107
#
# Epoch 00953: val_loss did not improve from 0.37701
# Epoch 954/1000
#  - 0s - loss: 0.4058 - acc: 0.8034 - val_loss: 0.3783 - val_acc: 0.8151
#
# Epoch 00954: val_loss did not improve from 0.37701
# Epoch 955/1000
#  - 0s - loss: 0.4045 - acc: 0.8037 - val_loss: 0.3773 - val_acc: 0.8107
#
# Epoch 00955: val_loss did not improve from 0.37701
# Epoch 956/1000
#  - 0s - loss: 0.4047 - acc: 0.8047 - val_loss: 0.3773 - val_acc: 0.8092
#
# Epoch 00956: val_loss did not improve from 0.37701
# Epoch 957/1000
#  - 0s - loss: 0.4047 - acc: 0.8039 - val_loss: 0.3774 - val_acc: 0.8114
#
# Epoch 00957: val_loss did not improve from 0.37701
# Epoch 958/1000
#  - 0s - loss: 0.4047 - acc: 0.8043 - val_loss: 0.3776 - val_acc: 0.8144
#
# Epoch 00958: val_loss did not improve from 0.37701
# Epoch 959/1000
#  - 0s - loss: 0.4046 - acc: 0.8030 - val_loss: 0.3778 - val_acc: 0.8166
#
# Epoch 00959: val_loss did not improve from 0.37701
# Epoch 960/1000
#  - 0s - loss: 0.4046 - acc: 0.8036 - val_loss: 0.3776 - val_acc: 0.8158
#
# Epoch 00960: val_loss did not improve from 0.37701
# Epoch 961/1000
#  - 0s - loss: 0.4050 - acc: 0.8036 - val_loss: 0.3780 - val_acc: 0.8151
#
# Epoch 00961: val_loss did not improve from 0.37701
# Epoch 962/1000
#  - 0s - loss: 0.4046 - acc: 0.8032 - val_loss: 0.3772 - val_acc: 0.8092
#
# Epoch 00962: val_loss did not improve from 0.37701
# Epoch 963/1000
#  - 0s - loss: 0.4050 - acc: 0.8047 - val_loss: 0.3772 - val_acc: 0.8122
#
# Epoch 00963: val_loss did not improve from 0.37701
# Epoch 964/1000
#  - 0s - loss: 0.4044 - acc: 0.8039 - val_loss: 0.3775 - val_acc: 0.8151
#
# Epoch 00964: val_loss did not improve from 0.37701
# Epoch 965/1000
#  - 0s - loss: 0.4044 - acc: 0.8028 - val_loss: 0.3780 - val_acc: 0.8151
#
# Epoch 00965: val_loss did not improve from 0.37701
# Epoch 966/1000
#  - 0s - loss: 0.4046 - acc: 0.8026 - val_loss: 0.3780 - val_acc: 0.8144
#
# Epoch 00966: val_loss did not improve from 0.37701
# Epoch 967/1000
#  - 0s - loss: 0.4043 - acc: 0.8036 - val_loss: 0.3774 - val_acc: 0.8122
#
# Epoch 00967: val_loss did not improve from 0.37701
# Epoch 968/1000
#  - 0s - loss: 0.4052 - acc: 0.8058 - val_loss: 0.3770 - val_acc: 0.8092
#
# Epoch 00968: val_loss improved from 0.37701 to 0.37695, saving model to best_model.h5
# Epoch 969/1000
#  - 0s - loss: 0.4044 - acc: 0.8034 - val_loss: 0.3775 - val_acc: 0.8151
#
# Epoch 00969: val_loss did not improve from 0.37695
# Epoch 970/1000
#  - 0s - loss: 0.4044 - acc: 0.8045 - val_loss: 0.3776 - val_acc: 0.8173
#
# Epoch 00970: val_loss did not improve from 0.37695
# Epoch 971/1000
#  - 0s - loss: 0.4044 - acc: 0.8026 - val_loss: 0.3781 - val_acc: 0.8158
#
# Epoch 00971: val_loss did not improve from 0.37695
# Epoch 972/1000
#  - 0s - loss: 0.4048 - acc: 0.8030 - val_loss: 0.3777 - val_acc: 0.8166
#
# Epoch 00972: val_loss did not improve from 0.37695
# Epoch 973/1000
#  - 0s - loss: 0.4045 - acc: 0.8028 - val_loss: 0.3771 - val_acc: 0.8114
#
# Epoch 00973: val_loss did not improve from 0.37695
# Epoch 974/1000
#  - 0s - loss: 0.4047 - acc: 0.8052 - val_loss: 0.3769 - val_acc: 0.8085
#
# Epoch 00974: val_loss improved from 0.37695 to 0.37692, saving model to best_model.h5
# Epoch 975/1000
#  - 0s - loss: 0.4045 - acc: 0.8045 - val_loss: 0.3783 - val_acc: 0.8166
#
# Epoch 00975: val_loss did not improve from 0.37692
# Epoch 976/1000
#  - 0s - loss: 0.4048 - acc: 0.8036 - val_loss: 0.3772 - val_acc: 0.8136
#
# Epoch 00976: val_loss did not improve from 0.37692
# Epoch 977/1000
#  - 0s - loss: 0.4042 - acc: 0.8041 - val_loss: 0.3775 - val_acc: 0.8173
#
# Epoch 00977: val_loss did not improve from 0.37692
# Epoch 978/1000
#  - 0s - loss: 0.4045 - acc: 0.8041 - val_loss: 0.3780 - val_acc: 0.8136
#
# Epoch 00978: val_loss did not improve from 0.37692
# Epoch 979/1000
#  - 0s - loss: 0.4047 - acc: 0.8037 - val_loss: 0.3769 - val_acc: 0.8092
#
# Epoch 00979: val_loss improved from 0.37692 to 0.37690, saving model to best_model.h5
# Epoch 980/1000
#  - 0s - loss: 0.4045 - acc: 0.8050 - val_loss: 0.3775 - val_acc: 0.8166
#
# Epoch 00980: val_loss did not improve from 0.37690
# Epoch 981/1000
#  - 0s - loss: 0.4043 - acc: 0.8032 - val_loss: 0.3781 - val_acc: 0.8144
#
# Epoch 00981: val_loss did not improve from 0.37690
# Epoch 982/1000
#  - 0s - loss: 0.4046 - acc: 0.8030 - val_loss: 0.3780 - val_acc: 0.8136
#
# Epoch 00982: val_loss did not improve from 0.37690
# Epoch 983/1000
#  - 0s - loss: 0.4050 - acc: 0.8047 - val_loss: 0.3767 - val_acc: 0.8085
#
# Epoch 00983: val_loss improved from 0.37690 to 0.37672, saving model to best_model.h5
# Epoch 984/1000
#  - 0s - loss: 0.4048 - acc: 0.8048 - val_loss: 0.3775 - val_acc: 0.8173
#
# Epoch 00984: val_loss did not improve from 0.37672
# Epoch 985/1000
#  - 0s - loss: 0.4047 - acc: 0.8045 - val_loss: 0.3774 - val_acc: 0.8173
#
# Epoch 00985: val_loss did not improve from 0.37672
# Epoch 986/1000
#  - 0s - loss: 0.4045 - acc: 0.8034 - val_loss: 0.3769 - val_acc: 0.8107
#
# Epoch 00986: val_loss did not improve from 0.37672
# Epoch 987/1000
#  - 0s - loss: 0.4044 - acc: 0.8039 - val_loss: 0.3776 - val_acc: 0.8151
#
# Epoch 00987: val_loss did not improve from 0.37672
# Epoch 988/1000
#  - 0s - loss: 0.4044 - acc: 0.8037 - val_loss: 0.3770 - val_acc: 0.8136
#
# Epoch 00988: val_loss did not improve from 0.37672
# Epoch 989/1000
#  - 0s - loss: 0.4042 - acc: 0.8039 - val_loss: 0.3778 - val_acc: 0.8136
#
# Epoch 00989: val_loss did not improve from 0.37672
# Epoch 990/1000
#  - 0s - loss: 0.4041 - acc: 0.8028 - val_loss: 0.3774 - val_acc: 0.8151
#
# Epoch 00990: val_loss did not improve from 0.37672
# Epoch 991/1000
#  - 0s - loss: 0.4045 - acc: 0.8058 - val_loss: 0.3767 - val_acc: 0.8107
#
# Epoch 00991: val_loss did not improve from 0.37672
# Epoch 992/1000
#  - 0s - loss: 0.4042 - acc: 0.8047 - val_loss: 0.3771 - val_acc: 0.8136
#
# Epoch 00992: val_loss did not improve from 0.37672
# Epoch 993/1000
#  - 0s - loss: 0.4055 - acc: 0.8021 - val_loss: 0.3790 - val_acc: 0.8158
#
# Epoch 00993: val_loss did not improve from 0.37672
# Epoch 994/1000
#  - 0s - loss: 0.4039 - acc: 0.8036 - val_loss: 0.3769 - val_acc: 0.8114
#
# Epoch 00994: val_loss did not improve from 0.37672
# Epoch 995/1000
#  - 0s - loss: 0.4041 - acc: 0.8039 - val_loss: 0.3766 - val_acc: 0.8092
#
# Epoch 00995: val_loss improved from 0.37672 to 0.37656, saving model to best_model.h5
# Epoch 996/1000
#  - 0s - loss: 0.4043 - acc: 0.8058 - val_loss: 0.3768 - val_acc: 0.8114
#
# Epoch 00996: val_loss did not improve from 0.37656
# Epoch 997/1000
#  - 0s - loss: 0.4037 - acc: 0.8043 - val_loss: 0.3779 - val_acc: 0.8151
#
# Epoch 00997: val_loss did not improve from 0.37656
# Epoch 998/1000
#  - 0s - loss: 0.4043 - acc: 0.8041 - val_loss: 0.3784 - val_acc: 0.8151
#
# Epoch 00998: val_loss did not improve from 0.37656
# Epoch 999/1000
#  - 0s - loss: 0.4039 - acc: 0.8030 - val_loss: 0.3771 - val_acc: 0.8166
#
# Epoch 00999: val_loss did not improve from 0.37656
# Epoch 1000/1000
#  - 0s - loss: 0.4039 - acc: 0.8048 - val_loss: 0.3765 - val_acc: 0.8085
#
# Epoch 01000: val_loss improved from 0.37656 to 0.37651, saving model to best_model.h5
# Train: 0.806, Test: 0.767

# %%
[loss_test,acc_test]=model.evaluate(x=test_X,y=test_y,batch_size=None, verbose=1)
# Out:
# 59/59 [==============================] - 0s 239us/step

# %%
print(loss_test,acc_test)
# Out:
# 0.47224610033681835 0.7668030565067873

# %%
model.metrics_names
# Out:
# ['loss', 'acc']

# %%
# metric_out_df= pd.DataFrame(np.array([train_acc,train_loss,test_acc,test_loss,neurons]).reshape(-1,14),columns =["accuracy","precision","recall","f1_score","auc","loss","accuracy_val","loss_val","accuracy_test","loss_test","neurons","learning_rate","n_epochs","steps"])

metric_out_df= pd.DataFrame(np.array([train_acc,train_loss,test_acc,test_loss,neurons]).reshape(-1,5),columns =["accuracy","loss","accuracy_test","loss_test","neurons"])

# %%
metric_out_df
# Out:
#    accuracy      loss  accuracy_test  loss_test  neurons
# 0  0.806163  0.398652       0.766803   0.472246      8.0

# %%
prob_train =  model.predict_proba(train_X)
prob_test  =  model.predict_proba(test_X)

# %%
prob_train_df  = pd.DataFrame(prob_train.reshape(prob_train.shape[0], prob_train.shape[1] ))
prob_test_df  = pd.DataFrame(prob_test.reshape(prob_test.shape[0], prob_test.shape[1] ))

# %%
for ep in range(0,10):
    plt.plot(prob_train[ep,:])
plt.plot(prob_train_df.mean(),linewidth=2,color="black"); 
plt.ylim([0,1])
plt.xlabel('trials')
plt.ylabel('P[gamble]')
# Out:
# Text(0, 0.5, 'P[gamble]')
